# %% [markdown]
# Some testing codes

# %%
import os

def read_voxceleb_trials(trial_file):
    """Reads the VoxCeleb1 trial file."""
    pairs = []
    with open(trial_file, 'r') as f:
        for line in f:
            label, path1, path2 = line.strip().split()
            pairs.append((path1, path2, int(label)))
    return pairs

trial_file = "/path/to/voxceleb1_trials.txt"
trials = read_voxceleb_trials(trial_file)
print(f"Loaded {len(trials)} test pairs.")

# %%
import numpy as np
from sklearn.metrics import roc_curve

# Example: Scores from cosine similarity (replace with actual values)
genuine_scores = np.array([0.85, 0.92, 0.88, 0.91])  # Same speaker
impostor_scores = np.array([0.30, 0.45, 0.28, 0.40])  # Different speakers

# Assign labels
genuine_labels = np.ones_like(genuine_scores)  # 1 for same speaker
impostor_labels = np.zeros_like(impostor_scores)  # 0 for different speaker

# Combine scores and labels
scores = np.concatenate([genuine_scores, impostor_scores])
labels = np.concatenate([genuine_labels, impostor_labels])

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(labels, scores, pos_label=1)

# Compute EER where FAR ≈ FRR
fnr = 1 - tpr  # False Negative Rate
eer_threshold = thresholds[np.nanargmin(np.abs(fpr - fnr))]
eer = fpr[np.nanargmin(np.abs(fpr - fnr))]

print(f"Equal Error Rate (EER): {eer:.4f}")
print(f"EER Threshold: {eer_threshold:.4f}")
# Out:
# Equal Error Rate (EER): 0.0000
# EER Threshold: 0.8500

# %%
import os

voxceleb_path = "./wav"  # Change this to your actual dataset path
print(f"Dataset path: {voxceleb_path}")
print(f"Path exists: {os.path.exists(voxceleb_path)}")
# Out:
# Dataset path: ./wav
# Path exists: True

# %% [markdown]
# Code for generating Embeddings using Pretrained Titanet

# %%
import os
import pickle
import numpy as np
import torch
from nemo.collections.asr.models import EncDecSpeakerLabelModel
from omegaconf import OmegaConf
from tqdm import tqdm

def load_titanet():
    """Load the Titanet speaker embedding model."""
    model = EncDecSpeakerLabelModel.from_pretrained(model_name="titanet_large")
    model.eval()
    return model

def extract_embedding(model, audio_path):
    """Extract speaker embedding from an audio file using the correct API."""
    with torch.no_grad():
        embedding = model.get_embedding(audio_path).cpu().numpy().flatten()
    return embedding

def process_voxceleb(voxceleb_dir, model, output_pickle, output_txt):
    """Process all audio files in the VoxCeleb directory and store embeddings."""
    embeddings = {}
    
    with open(output_txt, "w") as txt_file:
        for root, _, files in os.walk(voxceleb_dir):
            for file in tqdm(files):
                if file.endswith(".wav"):
                    file_path = os.path.join(root, file)
                    speaker_id = os.path.basename(root)  # Assuming structure: VoxCeleb/speaker_id/audio.wav
                    key = f"{speaker_id}@{file}"
                    embedding = extract_embedding(model, file_path)
                    embeddings[key] = embedding
                    
                    # Save in text format
                    txt_file.write(f"{key}: {embedding.tolist()}\n")
    
    with open(output_pickle, "wb") as f:
        pickle.dump(embeddings, f)
    print(f"Embeddings saved to {output_pickle} and {output_txt}")

if __name__ == "__main__":
    voxceleb_dir = "./wav"  # Change this to your local VoxCeleb directory
    output_pickle = "speaker_embeddings.pkl"
    output_txt = "speaker_embeddings.txt"
    
    model = load_titanet()
    process_voxceleb(voxceleb_dir, model, output_pickle, output_txt)
# Out:
# [NeMo I 2025-03-29 19:46:15 cloud:58] Found existing object C:\Users\hp\.cache\torch\NeMo\NeMo_2.2.0\titanet-l\11ba0924fdf87c049e339adbf6899d48\titanet-l.nemo.
# [NeMo I 2025-03-29 19:46:15 cloud:64] Re-using file from: C:\Users\hp\.cache\torch\NeMo\NeMo_2.2.0\titanet-l\11ba0924fdf87c049e339adbf6899d48\titanet-l.nemo
# [NeMo I 2025-03-29 19:46:15 common:826] Instantiating model from pre-trained checkpoint
# [NeMo W 2025-03-29 19:46:15 modelPT:176] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/train.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 64
#     shuffle: true
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       noise:
#         manifest_path: /manifests/noise/rir_noise_manifest.json
#         prob: 0.5
#         min_snr_db: 0
#         max_snr_db: 15
#       speed:
#         prob: 0.5
#         sr: 16000
#         resample_type: kaiser_fast
#         min_speed_rate: 0.95
#         max_speed_rate: 1.05
#     num_workers: 15
#     pin_memory: true
#
# [NeMo W 2025-03-29 19:46:15 modelPT:183] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/dev.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 128
#     shuffle: false
#     num_workers: 15
#     pin_memory: true
# [NeMo I 2025-03-29 19:46:15 features:305] PADDING: 16
# [NeMo I 2025-03-29 19:46:15 save_restore_connector:275] Model EncDecSpeakerLabelModel was successfully restored from C:\Users\hp\.cache\torch\NeMo\NeMo_2.2.0\titanet-l\11ba0924fdf87c049e339adbf6899d48\titanet-l.nemo.
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 27/27 [00:04<00:00,  6.20it/s]
# 100%|██████████| 2/2 [00:00<00:00,  6.42it/s]
# 100%|██████████| 38/38 [00:04<00:00,  7.92it/s]
# 100%|██████████| 55/55 [00:08<00:00,  6.86it/s]
# 100%|██████████| 8/8 [00:00<00:00,  8.61it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.05it/s]
# 100%|██████████| 3/3 [00:00<00:00,  7.71it/s]
# 100%|██████████| 1/1 [00:00<00:00,  8.30it/s]
# 100%|██████████| 20/20 [00:02<00:00,  7.41it/s]
# 100%|██████████| 3/3 [00:00<00:00,  7.81it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 21/21 [00:02<00:00,  8.17it/s]
# 100%|██████████| 3/3 [00:00<00:00,  9.02it/s]
# 100%|██████████| 1/1 [00:00<00:00,  9.72it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.85it/s]
# 100%|██████████| 3/3 [00:00<00:00,  8.86it/s]
# 100%|██████████| 7/7 [00:00<00:00,  7.12it/s]
# 100%|██████████| 8/8 [00:00<00:00,  9.65it/s]
# 100%|██████████| 1/1 [00:00<00:00,  8.75it/s]
# 100%|██████████| 8/8 [00:00<00:00,  8.20it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.60it/s]
# 100%|██████████| 1/1 [00:00<00:00,  8.10it/s]
# 100%|██████████| 4/4 [00:00<00:00, 10.95it/s]
# 100%|██████████| 8/8 [00:01<00:00,  7.26it/s]
# 100%|██████████| 1/1 [00:00<00:00,  7.50it/s]
# 100%|██████████| 5/5 [00:00<00:00,  6.93it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 6/6 [00:00<00:00,  7.05it/s]
# 100%|██████████| 1/1 [00:00<00:00, 10.01it/s]
# 100%|██████████| 8/8 [00:01<00:00,  6.70it/s]
# 100%|██████████| 5/5 [00:00<00:00,  9.67it/s]
# 100%|██████████| 14/14 [00:02<00:00,  6.95it/s]
# 100%|██████████| 3/3 [00:00<00:00, 10.25it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12.36it/s]
# 100%|██████████| 1/1 [00:00<00:00,  8.56it/s]
# 100%|██████████| 1/1 [00:00<00:00,  8.56it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.79it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.48it/s]
# 100%|██████████| 4/4 [00:00<00:00,  5.78it/s]
# 100%|██████████| 1/1 [00:00<00:00,  6.16it/s]
# 100%|██████████| 5/5 [00:00<00:00,  9.65it/s]
# 100%|██████████| 12/12 [00:01<00:00,  8.28it/s]
# 100%|██████████| 41/41 [00:06<00:00,  6.49it/s]
# 100%|██████████| 15/15 [00:04<00:00,  3.57it/s]
# 100%|██████████| 3/3 [00:00<00:00,  6.25it/s]
# 100%|██████████| 2/2 [00:00<00:00,  4.83it/s]
# 100%|██████████| 7/7 [00:00<00:00,  7.29it/s]
# 100%|██████████| 6/6 [00:00<00:00,  7.65it/s]
# 100%|██████████| 26/26 [00:05<00:00,  4.95it/s]
# 100%|██████████| 9/9 [00:01<00:00,  5.55it/s]
# 100%|██████████| 6/6 [00:01<00:00,  5
    model.eval()
    return model

def extract_embedding(model, audio_path):
    """Extract speaker embedding from an audio file using the correct API."""
    with torch.no_grad():
        embedding = model.get_embedding(audio_path).cpu().numpy().flatten()
    return embedding

def process_voxceleb(voxceleb_dir, model, output_pickle, output_txt):
    """Process all audio files in the VoxCeleb directory and store embeddings."""
    embeddings = {}
    
    with open(output_txt, "w") as txt_file:
        for root, dirs, files in os.walk(voxceleb_dir):
            if files:  # Only process if there are audio files
                speaker_id = os.path.basename(os.path.dirname(root))  # Get the speaker ID from the parent directory
                for file in tqdm(files):
                    if file.endswith(".wav"):
                        file_path = os.path.join(root, file)
                        key = f"{speaker_id}@{file}"
                        embedding = extract_embedding(model, file_path)
                        embeddings[key] = embedding
                        
                        # Save in text format
                        txt_file.write(f"{key}: {embedding.tolist()}\n")
    
    with open(output_pickle, "wb") as f:
        pickle.dump(embeddings, f)
    print(f"Embeddings saved to {output_pickle} and {output_txt}")

if __name__ == "__main__":
    voxceleb_dir = "./segregated/English"  # Change this to your local VoxCeleb directory
    output_pickle = "speaker_embeddings-IMSV_English.pkl"
    output_txt = "speaker_embeddings-mera-IMSV_English.txt"
    
    model = load_titanet()
    process_voxceleb(voxceleb_dir, model, output_pickle, output_txt)

# %%
import os
import re

def verify_files(text_file, root_directory):
    with open(text_file, 'r') as f:
        missing_files = []
        for line in f:
            line = line.strip()
            match = re.match(r"(\w+)@([\w.]+)", line)
            if match:
                folder, filename = match.groups()
                folder_path = os.path.join(root_directory, folder)
                file_path = os.path.join(folder_path, filename)
                if not os.path.exists(file_path):
                    missing_files.append(file_path)
    
    if missing_files:
        print("The following files are missing:")
        for file in missing_files:
            print(file)
    else:
        print("All files are present.")

# Example usage
text_file = "./speaker_embeddings.txt"  # Text file containing the filenames
root_directory = "./wav"  # Update this to your actual root folder
verify_files(text_file, root_directory)

# %%
import re

def remove_middle_folder(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line in infile:
            parts = line.strip().split()
            processed_parts = [parts[0]] + [re.sub(r'/[^/]+/', '/', path) for path in parts[1:]]
            outfile.write(" ".join(processed_parts) + "\n")

# Example usage:
input_file = "./vox-test.txt"  # Replace with your input filename
output_file = "./vox_test2.txt"  # Replace with your output filename
remove_middle_folder(input_file, output_file)

# %% [markdown]
# Code to segregate all language files

# %%
import os
import shutil

def segregate_audio_files(audio_dir):
    """
    Segregates audio files in the given directory into subfolders based on the
    language code in their filenames, following the IITG-MV database naming convention.

    Args:
        audio_dir (str): The path to the directory containing the audio files.
    """

    language_codes = {
        "AS": "Assamese",
        "BN": "Bengali",
        "BD": "Bodo",
        "DG": "Dogri",
        "EN": "English",
        "GJ": "Gujarati",
        "HN": "Hindi",
        "KN": "Kannada",
        "KS": "Kashmiri",
        "KK": "Konkani",
        "MT": "Maithili",
        "MN": "Manipuri",
        "MR": "Marathi",
        "NP": "Nepali",
        "OR": "Oriya",
        "PN": "Punjabi",
        "SN": "Sanskrit",
        "ST": "Santali",
        "SD": "Sindhi",
        "TM": "Tamil",
        "TL": "Telugu",
        "UR": "Urdu",
        "ML": "Malayalam",
        "MZ": "Mizo"
    }

    for filename in os.listdir(audio_dir):
        if filename.endswith(".wav") or filename.endswith(".mp3") or filename.endswith(".amr"):
            parts = filename.split("_")
            if len(parts) > 1:
                recording_conditions = parts[1].split(".")[0]
                if len(recording_conditions) >= 6:
                    language_code = recording_conditions[-3:-1]
                    if language_code in language_codes:
                        language_name = language_codes[language_code]
                        language_folder = os.path.join(audio_dir, language_name)
                        os.makedirs(language_folder, exist_ok=True)
                        source_path = os.path.join(audio_dir, filename)
                        destination_path = os.path.join(language_folder, filename)
                        shutil.move(source_path, destination_path)
                        print(f"Moved '{filename}' to '{language_name}' folder.")
                    else:
                        print(f"Could not identify language for '{filename}'. Extracted code: '{language_code}'")
                else:
                    print(f"Filename '{filename}' does not follow the expected format: '{filename}'")
            else:
                print(f"Filename '{filename}' does not follow the expected format: '{filename}'")

if __name__ == "__main__":
    audio_directory = input("Enter the directory containing the audio files: ")
    segregate_audio_files(audio_directory)
    print("Audio file segregation complete.")
# Out:
# Moved '1043_BD01OENC.wav' to 'English' folder.
# Moved '1043_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1043_BH01OENC.wav' to 'English' folder.
# Moved '1043_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1043_BM01OENC.wav' to 'English' folder.
# Moved '1043_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1043_BM02OENC.wav' to 'English' folder.
# Moved '1043_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1043_BT01OENC.wav' to 'English' folder.
# Moved '1043_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1066_BD01OENC.wav' to 'English' folder.
# Moved '1066_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1066_BH01OENC.wav' to 'English' folder.
# Moved '1066_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1066_BM01OENC.wav' to 'English' folder.
# Moved '1066_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1066_BM02OENC.wav' to 'English' folder.
# Moved '1066_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1066_BT01OENC.wav' to 'English' folder.
# Moved '1066_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1067_BD01OENC.wav' to 'English' folder.
# Moved '1067_BD01OORC.wav' to 'Oriya' folder.
# Moved '1067_BH01OENC.wav' to 'English' folder.
# Moved '1067_BH01OORC.wav' to 'Oriya' folder.
# Moved '1067_BM01OENC.wav' to 'English' folder.
# Moved '1067_BM01OORC.wav' to 'Oriya' folder.
# Moved '1067_BM02OENC.wav' to 'English' folder.
# Moved '1067_BM02OORC.wav' to 'Oriya' folder.
# Moved '1067_BT01OENC.wav' to 'English' folder.
# Moved '1067_BT01OORC.wav' to 'Oriya' folder.
# Moved '1068_BD01OENC.wav' to 'English' folder.
# Moved '1068_BD01OORC.wav' to 'Oriya' folder.
# Moved '1068_BH01OENC.wav' to 'English' folder.
# Moved '1068_BH01OORC.wav' to 'Oriya' folder.
# Moved '1068_BM01OENC.wav' to 'English' folder.
# Moved '1068_BM01OORC.wav' to 'Oriya' folder.
# Moved '1068_BM02OENC.wav' to 'English' folder.
# Moved '1068_BM02OORC.wav' to 'Oriya' folder.
# Moved '1068_BT01OENC.wav' to 'English' folder.
# Moved '1068_BT01OORC.wav' to 'Oriya' folder.
# Moved '1069_BD01OENC.wav' to 'English' folder.
# Moved '1069_BD01OORC.wav' to 'Oriya' folder.
# Moved '1069_BH01OENC.wav' to 'English' folder.
# Moved '1069_BH01OORC.wav' to 'Oriya' folder.
# Moved '1069_BM01OENC.wav' to 'English' folder.
# Moved '1069_BM01OORC.wav' to 'Oriya' folder.
# Moved '1069_BM02OENC.wav' to 'English' folder.
# Moved '1069_BM02OORC.wav' to 'Oriya' folder.
# Moved '1069_BT01OENC.wav' to 'English' folder.
# Moved '1069_BT01OORC.wav' to 'Oriya' folder.
# Moved '1070_BD01OENC.wav' to 'English' folder.
# Moved '1070_BD01OORC.wav' to 'Oriya' folder.
# Moved '1070_BH01OENC.wav' to 'English' folder.
# Moved '1070_BH01OORC.wav' to 'Oriya' folder.
# Moved '1070_BM01OENC.wav' to 'English' folder.
# Moved '1070_BM01OORC.wav' to 'Oriya' folder.
# Moved '1070_BM02OENC.wav' to 'English' folder.
# Moved '1070_BM02OORC.wav' to 'Oriya' folder.
# Moved '1070_BT01OENC.wav' to 'English' folder.
# Moved '1070_BT01OORC.wav' to 'Oriya' folder.
# Moved '1071_BD01OENC.wav' to 'English' folder.
# Moved '1071_BD01OMLC.wav' to 'Malayalam' folder.
# Moved '1071_BH01OENC.wav' to 'English' folder.
# Moved '1071_BH01OMLC.wav' to 'Malayalam' folder.
# Moved '1071_BM01OENC.wav' to 'English' folder.
# Moved '1071_BM01OMLC.wav' to 'Malayalam' folder.
# Moved '1071_BM02OENC.wav' to 'English' folder.
# Moved '1071_BM02OMLC.wav' to 'Malayalam' folder.
# Moved '1071_BT01OENC.wav' to 'English' folder.
# Moved '1071_BT01OMLC.wav' to 'Malayalam' folder.
# Moved '1072_BD01OENC.wav' to 'English' folder.
# Moved '1072_BD01OGJC.wav' to 'Gujarati' folder.
# Moved '1072_BH01OENC.wav' to 'English' folder.
# Moved '1072_BH01OGJC.wav' to 'Gujarati' folder.
# Moved '1072_BM01OENC.wav' to 'English' folder.
# Moved '1072_BM01OGJC.wav' to 'Gujarati' folder.
# Moved '1072_BM02OENC.wav' to 'English' folder.
# Moved '1072_BM02OGJC.wav' to 'Gujarati' folder.
# Moved '1072_BT01OENC.wav' to 'English' folder.
# Moved '1072_BT01OGJC.wav' to 'Gujarati' folder.
# Moved '1073_BD01OENC.wav' to 'English' folder.
# Moved '1073_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1073_BH01OENC.wav' to 'English' folder.
# Moved '1073_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1073_BM01OENC.wav' to 'English' folder.
# Moved '1073_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1073_BM02OENC.wav' to 'English' folder.
# Moved '1073_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1073_BT01OENC.wav' to 'English' folder.
# Moved '1073_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1074_BD01OENC.wav' to 'English' folder.
# Moved '1074_BD01OORC.wav' to 'Oriya' folder.
# Moved '1074_BH01OENC.wav' to 'English' folder.
# Moved '1074_BH01OORC.wav' to 'Oriya' folder.
# Moved '1074_BM01OENC.wav' to 'English' folder.
# Moved '1074_BM01OORC.wav' to 'Oriya' folder.
# Moved '1074_BM02OENC.wav' to 'English' folder.
# Moved '1074_BM02OORC.wav' to 'Oriya' folder.
# Moved '1074_BT01OENC.wav' to 'English' folder.
# Moved '1074_BT01OORC.wav' to 'Oriya' folder.
# Moved '1075_BD01OENC.wav' to 'English' folder.
# Moved '1075_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1075_BH01OENC.wav' to 'English' folder.
# Moved '1075_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1075_BM01OENC.wav' to 'English' folder.
# Moved '1075_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1075_BM02OENC.wav' to 'English' folder.
# Moved '1075_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1075_BT01OENC.wav' to 'English' folder.
# Moved '1075_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1076_BD01OENC.wav' to 'English' folder.
# Moved '1076_BD01OMLC.wav' to 'Malayalam' folder.
# Moved '1076_BH01OENC.wav' to 'English' folder.
# Moved '1076_BH01OMLC.wav' to 'Malayalam' folder.
# Moved '1076_BM01OENC.wav' to 'English' folder.
# Moved '1076_BM01OMLC.wav' to 'Malayalam' folder.
# Moved '1076_BM02OENC.wav' to 'English' folder.
# Moved '1076_BM02OMLC.wav' to 'Malayalam' folder.
# Moved '1076_BT01OENC.wav' to 'English' folder.
# Moved '1076_BT01OMLC.wav' to 'Malayalam' folder.
# Moved '1077_BD01OENC.wav' to 'English' folder.
# Moved '1077_BD01OORC.wav' to 'Oriya' folder.
# Moved '1077_BH01OENC.wav' to 'English' folder.
# Moved '1077_BH01OORC.wav' to 'Oriya' folder.
# Moved '1077_BM01OENC.wav' to 'English' folder.
# Moved '1077_BM01OORC.wav' to 'Oriya' folder.
# Moved '1077_BM02OENC.wav' to 'English' folder.
# Moved '1077_BM02OORC.wav' to 'Oriya' folder.
# Moved '1077_BT01OENC.wav' to 'English' folder.
# Moved '1077_BT01OORC.wav' to 'Oriya' folder.
# Moved '1078_BD01OENC.wav' to 'English' folder.
# Moved '1078_BD01OKNC.wav' to 'Kannada' folder.
# Moved '1078_BH01OENC.wav' to 'English' folder.
# Moved '1078_BH01OKNC.wav' to 'Kannada' folder.
# Moved '1078_BM01OENC.wav' to 'English' folder.
# Moved '1078_BM01OKNC.wav' to 'Kannada' folder.
# Moved '1078_BM02OENC.wav' to 'English' folder.
# Moved '1078_BM02OKNC.wav' to 'Kannada' folder.
# Moved '1078_BT01OENC.wav' to 'English' folder.
# Moved '1078_BT01OKNC.wav' to 'Kannada' folder.
# Moved '1079_BD01OENC.wav' to 'English' folder.
# Moved '1079_BD01OORC.wav' to 'Oriya' folder.
# Moved '1079_BH01OENC.wav' to 'English' folder.
# Moved '1079_BH01OORC.wav' to 'Oriya' folder.
# Moved '1079_BM01OENC.wav' to 'English' folder.
# Moved '1079_BM01OORC.wav' to 'Oriya' folder.
# Moved '1079_BM02OENC.wav' to 'English' folder.
# Moved '1079_BM02OORC.wav' to 'Oriya' folder.
# Moved '1079_BT01OENC.wav' to 'English' folder.
# Moved '1079_BT01OORC.wav' to 'Oriya' folder.
# Moved '1080_BD01OENC.wav' to 'English' folder.
# Moved '1080_BD01OTMC.wav' to 'Tamil' folder.
# Moved '1080_BH01OENC.wav' to 'English' folder.
# Moved '1080_BH01OTMC.wav' to 'Tamil' folder.
# Moved '1080_BM01OENC.wav' to 'English' folder.
# Moved '1080_BM01OTMC.wav' to 'Tamil' folder.
# Moved '1080_BM02OENC.wav' to 'English' folder.
# Moved '1080_BM02OTMC.wav' to 'Tamil' folder.
# Moved '1080_BT01OENC.wav' to 'English' folder.
# Moved '1080_BT01OTMC.wav' to 'Tamil' folder.
# Moved '1081_BD01OENC.wav' to 'English' folder.
# Moved '1081_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1081_BH01OENC.wav' to 'English' folder.
# Moved '1081_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1081_BM01OENC.wav' to 'English' folder.
# Moved '1081_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1081_BM02OENC.wav' to 'English' folder.
# Moved '1081_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1081_BT01OENC.wav' to 'English' folder.
# Moved '1081_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1082_BD01OASC.wav' to 'Assamese' folder.
# Moved '1082_BD01OENC.wav' to 'English' folder.
# Moved '1082_BH01OASC.wav' to 'Assamese' folder.
# Moved '1082_BH01OENC.wav' to 'English' folder.
# Moved '1082_BM01OASC.wav' to 'Assamese' folder.
# Moved '1082_BM01OENC.wav' to 'English' folder.
# Moved '1082_BM02OASC.wav' to 'Assamese' folder.
# Moved '1082_BM02OENC.wav' to 'English' folder.
# Moved '1082_BT01OASC.wav' to 'Assamese' folder.
# Moved '1082_BT01OENC.wav' to 'English' folder.
# Moved '1084_BD01OENC.wav' to 'English' folder.
# Moved '1084_BD01OORC.wav' to 'Oriya' folder.
# Moved '1084_BH01OENC.wav' to 'English' folder.
# Moved '1084_BH01OORC.wav' to 'Oriya' folder.
# Moved '1084_BM01OENC.wav' to 'English' folder.
# Moved '1084_BM01OORC.wav' to 'Oriya' folder.
# Moved '1084_BM02OENC.wav' to 'English' folder.
# Moved '1084_BM02OORC.wav' to 'Oriya' folder.
# Moved '1084_BT01OENC.wav' to 'English' folder.
# Moved '1084_BT01OORC.wav' to 'Oriya' folder.
# Moved '1085_BD01OBNC.wav' to 'Bengali' folder.
# Moved '1085_BD01OENC.wav' to 'English' folder.
# Moved '1085_BH01OBNC.wav' to 'Bengali' folder.
# Moved '1085_BH01OENC.wav' to 'English' folder.
# Moved '1085_BM01OBNC.wav' to 'Bengali' folder.
# Moved '1085_BM01OENC.wav' to 'English' folder.
# Moved '1085_BM02OBNC.wav' to 'Bengali' folder.
# Moved '1085_BM02OENC.wav' to 'English' folder.
# Moved '1085_BT01OBNC.wav' to 'Bengali' folder.
# Moved '1085_BT01OENC.wav' to 'English' folder.
# Moved '1086_BD01OENC.wav' to 'English' folder.
# Moved '1086_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1086_BH01OENC.wav' to 'English' folder.
# Moved '1086_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1086_BM01OENC.wav' to 'English' folder.
# Moved '1086_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1086_BM02OENC.wav' to 'English' folder.
# Moved '1086_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1086_BT01OENC.wav' to 'English' folder.
# Moved '1086_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1087_BD01OENC.wav' to 'English' folder.
# Moved '1087_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1087_BH01OENC.wav' to 'English' folder.
# Moved '1087_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1087_BM01OENC.wav' to 'English' folder.
# Moved '1087_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1087_BM02OENC.wav' to 'English' folder.
# Moved '1087_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1087_BT01OENC.wav' to 'English' folder.
# Moved '1087_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1088_BD01OENC.wav' to 'English' folder.
# Moved '1088_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1088_BH01OENC.wav' to 'English' folder.
# Moved '1088_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1088_BM01OENC.wav' to 'English' folder.
# Moved '1088_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1088_BM02OENC.wav' to 'English' folder.
# Moved '1088_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1088_BT01OENC.wav' to 'English' folder.
# Moved '1088_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1089_BD01OENC.wav' to 'English' folder.
# Moved '1089_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1089_BH01OENC.wav' to 'English' folder.
# Moved '1089_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1089_BM01OENC.wav' to 'English' folder.
# Moved '1089_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1089_BM02OENC.wav' to 'English' folder.
# Moved '1089_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1089_BT01OENC.wav' to 'English' folder.
# Moved '1089_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1090_BD01OENC.wav' to 'English' folder.
# Moved '1090_BD01OMRC.wav' to 'Marathi' folder.
# Moved '1090_BH01OENC.wav' to 'English' folder.
# Moved '1090_BH01OMRC.wav' to 'Marathi' folder.
# Moved '1090_BM01OENC.wav' to 'English' folder.
# Moved '1090_BM01OMRC.wav' to 'Marathi' folder.
# Moved '1090_BM02OENC.wav' to 'English' folder.
# Moved '1090_BM02OMRC.wav' to 'Marathi' folder.
# Moved '1090_BT01OENC.wav' to 'English' folder.
# Moved '1090_BT01OMRC.wav' to 'Marathi' folder.
# Moved '1091_BD01OENC.wav' to 'English' folder.
# Moved '1091_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1091_BH01OENC.wav' to 'English' folder.
# Moved '1091_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1091_BM01OENC.wav' to 'English' folder.
# Moved '1091_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1091_BM02OENC.wav' to 'English' folder.
# Moved '1091_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1091_BT01OENC.wav' to 'English' folder.
# Moved '1091_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1092_BD01OENC.wav' to 'English' folder.
# Moved '1092_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1092_BH01OENC.wav' to 'English' folder.
# Moved '1092_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1092_BM01OENC.wav' to 'English' folder.
# Moved '1092_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1092_BM02OENC.wav' to 'English' folder.
# Moved '1092_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1092_BT01OENC.wav' to 'English' folder.
# Moved '1092_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1093_BD01OENC.wav' to 'English' folder.
# Moved '1093_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1093_BH01OENC.wav' to 'English' folder.
# Moved '1093_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1093_BM01OENC.wav' to 'English' folder.
# Moved '1093_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1093_BM02OENC.wav' to 'English' folder.
# Moved '1093_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1093_BT01OENC.wav' to 'English' folder.
# Moved '1093_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1094_BD01OENC.wav' to 'English' folder.
# Moved '1094_BD01OKNC.wav' to 'Kannada' folder.
# Moved '1094_BH01OENC.wav' to 'English' folder.
# Moved '1094_BH01OKNC.wav' to 'Kannada' folder.
# Moved '1094_BM01OENC.wav' to 'English' folder.
# Moved '1094_BM01OKNC.wav' to 'Kannada' folder.
# Moved '1094_BM02OENC.wav' to 'English' folder.
# Moved '1094_BM02OKNC.wav' to 'Kannada' folder.
# Moved '1094_BT01OENC.wav' to 'English' folder.
# Moved '1094_BT01OKNC.wav' to 'Kannada' folder.
# Moved '1095_BD01OENC.wav' to 'English' folder.
# Moved '1095_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1095_BH01OENC.wav' to 'English' folder.
# Moved '1095_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1095_BM01OENC.wav' to 'English' folder.
# Moved '1095_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1095_BM02OENC.wav' to 'English' folder.
# Moved '1095_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1095_BT01OENC.wav' to 'English' folder.
# Moved '1095_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1096_BD01OENC.wav' to 'English' folder.
# Moved '1096_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1096_BH01OENC.wav' to 'English' folder.
# Moved '1096_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1096_BM01OENC.wav' to 'English' folder.
# Moved '1096_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1096_BM02OENC.wav' to 'English' folder.
# Moved '1096_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1096_BT01OENC.wav' to 'English' folder.
# Moved '1096_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1098_BD01OENC.wav' to 'English' folder.
# Moved '1098_BD01OTMC.wav' to 'Tamil' folder.
# Moved '1098_BH01OENC.wav' to 'English' folder.
# Moved '1098_BH01OTMC.wav' to 'Tamil' folder.
# Moved '1098_BM01OENC.wav' to 'English' folder.
# Moved '1098_BM01OTMC.wav' to 'Tamil' folder.
# Moved '1098_BM02OENC.wav' to 'English' folder.
# Moved '1098_BM02OTMC.wav' to 'Tamil' folder.
# Moved '1098_BT01OENC.wav' to 'English' folder.
# Moved '1098_BT01OTMC.wav' to 'Tamil' folder.
# Moved '1099_BD01OENC.wav' to 'English' folder.
# Moved '1099_BD01OTMC.wav' to 'Tamil' folder.
# Moved '1099_BH01OENC.wav' to 'English' folder.
# Moved '1099_BH01OTMC.wav' to 'Tamil' folder.
# Moved '1099_BM01OENC.wav' to 'English' folder.
# Moved '1099_BM01OTMC.wav' to 'Tamil' folder.
# Moved '1099_BM02OENC.wav' to 'English' folder.
# Moved '1099_BM02OTMC.wav' to 'Tamil' folder.
# Moved '1099_BT01OENC.wav' to 'English' folder.
# Moved '1099_BT01OTMC.wav' to 'Tamil' folder.
# Moved '1101_BD01OENC.wav' to 'English' folder.
# Moved '1101_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1101_BH01OENC.wav' to 'English' folder.
# Moved '1101_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1101_BM01OENC.wav' to 'English' folder.
# Moved '1101_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1101_BM02OENC.wav' to 'English' folder.
# Moved '1101_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1101_BT01OENC.wav' to 'English' folder.
# Moved '1101_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1104_BD01OENC.wav' to 'English' folder.
# Moved '1104_BD01OTLC.wav' to 'Telugu' folder.
# Moved '1104_BH01OENC.wav' to 'English' folder.
# Moved '1104_BH01OTLC.wav' to 'Telugu' folder.
# Moved '1104_BM01OENC.wav' to 'English' folder.
# Moved '1104_BM01OTLC.wav' to 'Telugu' folder.
# Moved '1104_BM02OENC.wav' to 'English' folder.
# Moved '1104_BM02OTLC.wav' to 'Telugu' folder.
# Moved '1104_BT01OENC.wav' to 'English' folder.
# Moved '1104_BT01OTLC.wav' to 'Telugu' folder.
# Moved '1105_BD01OENC.wav' to 'English' folder.
# Moved '1105_BD01OTLC.wav' to 'Telugu' folder.
# Moved '1105_BH01OENC.wav' to 'English' folder.
# Moved '1105_BH01OTLC.wav' to 'Telugu' folder.
# Moved '1105_BM01OENC.wav' to 'English' folder.
# Moved '1105_BM01OTLC.wav' to 'Telugu' folder.
# Moved '1105_BM02OENC.wav' to 'English' folder.
# Moved '1105_BM02OTLC.wav' to 'Telugu' folder.
# Moved '1105_BT01OENC.wav' to 'English' folder.
# Moved '1105_BT01OTLC.wav' to 'Telugu' folder.
# Moved '1106_BD01OENC.wav' to 'English' folder.
# Moved '1106_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1106_BH01OENC.wav' to 'English' folder.
# Moved '1106_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1106_BM01OENC.wav' to 'English' folder.
# Moved '1106_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1106_BM02OENC.wav' to 'English' folder.
# Moved '1106_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1106_BT01OENC.wav' to 'English' folder.
# Moved '1106_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1107_BD01OENC.wav' to 'English' folder.
# Moved '1107_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1107_BH01OENC.wav' to 'English' folder.
# Moved '1107_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1107_BM01OENC.wav' to 'English' folder.
# Moved '1107_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1107_BM02OENC.wav' to 'English' folder.
# Moved '1107_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1107_BT01OENC.wav' to 'English' folder.
# Moved '1107_BT01OHNC.wav' to 'Hindi' folder.
# Moved '1108_BD01OENC.wav' to 'English' folder.
# Moved '1108_BD01OORC.wav' to 'Oriya' folder.
# Moved '1108_BH01OENC.wav' to 'English' folder.
# Moved '1108_BH01OORC.wav' to 'Oriya' folder.
# Moved '1108_BM01OENC.wav' to 'English' folder.
# Moved '1108_BM01OORC.wav' to 'Oriya' folder.
# Moved '1108_BM02OENC.wav' to 'English' folder.
# Moved '1108_BM02OORC.wav' to 'Oriya' folder.
# Moved '1108_BT01OENC.wav' to 'English' folder.
# Moved '1108_BT01OORC.wav' to 'Oriya' folder.
# Moved '1109_BD01OENC.wav' to 'English' folder.
# Moved '1109_BD01OHNC.wav' to 'Hindi' folder.
# Moved '1109_BH01OENC.wav' to 'English' folder.
# Moved '1109_BH01OHNC.wav' to 'Hindi' folder.
# Moved '1109_BM01OENC.wav' to 'English' folder.
# Moved '1109_BM01OHNC.wav' to 'Hindi' folder.
# Moved '1109_BM02OENC.wav' to 'English' folder.
# Moved '1109_BM02OHNC.wav' to 'Hindi' folder.
# Moved '1109_BT01OENC.wav' to 'English' folder.
# Moved '1109_BT01OHNC.wav' to 'Hindi' folder.
# Moved '2046_BD01OENC.wav' to 'English' folder.
# Moved '2046_BD01OHNC.wav' to 'Hindi' folder.
# Moved '2046_BH01OENC.wav' to 'English' folder.
# Moved '2046_BH01OHNC.wav' to 'Hindi' folder.
# Moved '2046_BM01OENC.wav' to 'English' folder.
# Moved '2046_BM01OHNC.wav' to 'Hindi' folder.
# Moved '2046_BM02OENC.wav' to 'English' folder.
# Moved '2046_BM02OHNC.wav' to 'Hindi' folder.
# Moved '2046_BT01OENC.wav' to 'English' folder.
# Moved '2046_BT01OHNC.wav' to 'Hindi' folder.
# Moved '2047_BD01OENC.wav' to 'English' folder.
# Moved '2047_BD01OHNC.wav' to 'Hindi' folder.
# Moved '2047_BH01OENC.wav' to 'English' folder.
# Moved '2047_BH01OHNC.wav' to 'Hindi' folder.
# Moved '2047_BM01OENC.wav' to 'English' folder.
# Moved '2047_BM01OHNC.wav' to 'Hindi' folder.
# Moved '2047_BM02OENC.wav' to 'English' folder.
# Moved '2047_BM02OHNC.wav' to 'Hindi' folder.
# Moved '2047_BT01OENC.wav' to 'English' folder.
# Moved '2047_BT01OHNC.wav' to 'Hindi' folder.
# Moved '2048_BD01OASC.wav' to 'Assamese' folder.
# Moved '2048_BD01OENC.wav' to 'English' folder.
# Moved '2048_BH01OASC.wav' to 'Assamese' folder.
# Moved '2048_BH01OENC.wav' to 'English' folder.
# Moved '2048_BM01OASC.wav' to 'Assamese' folder.
# Moved '2048_BM01OENC.wav' to 'English' folder.
# Moved '2048_BM02OASC.wav' to 'Assamese' folder.
# Moved '2048_BM02OENC.wav' to 'English' folder.
# Moved '2048_BT01OASC.wav' to 'Assamese' folder.
# Moved '2048_BT01OENC.wav' to 'English' folder.
# Moved '2050_BD01OENC.wav' to 'English' folder.
# Moved '2050_BD01OTMC.wav' to 'Tamil' folder.
# Moved '2050_BH01OENC.wav' to 'English' folder.
# Moved '2050_BH01OTMC.wav' to 'Tamil' folder.
# Moved '2050_BM01OENC.wav' to 'English' folder.
# Moved '2050_BM01OTMC.wav' to 'Tamil' folder.
# Moved '2050_BM02OENC.wav' to 'English' folder.
# Moved '2050_BM02OTMC.wav' to 'Tamil' folder.
# Moved '2050_BT01OENC.wav' to 'English' folder.
# Moved '2050_BT01OTMC.wav' to 'Tamil' folder.
# Moved '2056_BD01OBNC.wav' to 'Bengali' folder.
# Moved '2056_BD01OENC.wav' to 'English' folder.
# Moved '2056_BH01OBNC.wav' to 'Bengali' folder.
# Moved '2056_BH01OENC.wav' to 'English' folder.
# Moved '2056_BM01OBNC.wav' to 'Bengali' folder.
# Moved '2056_BM01OENC.wav' to 'English' folder.
# Moved '2056_BM02OBNC.wav' to 'Bengali' folder.
# Moved '2056_BM02OENC.wav' to 'English' folder.
# Moved '2056_BT01OBNC.wav' to 'Bengali' folder.
# Moved '2056_BT01OENC.wav' to 'English' folder.
# Moved '2083_BD01OENC.wav' to 'English' folder.
# Moved '2083_BD01OTMC.wav' to 'Tamil' folder.
# Moved '2083_BH01OENC.wav' to 'English' folder.
# Moved '2083_BH01OTMC.wav' to 'Tamil' folder.
# Moved '2083_BM01OENC.wav' to 'English' folder.
# Moved '2083_BM01OTMC.wav' to 'Tamil' folder.
# Moved '2083_BM02OENC.wav' to 'English' folder.
# Moved '2083_BM02OTMC.wav' to 'Tamil' folder.
# Moved '2083_BT01OENC.wav' to 'English' folder.
# Moved '2083_BT01OTMC.wav' to 'Tamil' folder.
# Moved '2097_BD01OENC.wav' to 'English' folder.
# Moved '2097_BD01OHNC.wav' to 'Hindi' folder.
# Moved '2097_BH01OENC.wav' to 'English' folder.
# Moved '2097_BH01OHNC.wav' to 'Hindi' folder.
# Moved '2097_BM01OENC.wav' to 'English' folder.
# Moved '2097_BM01OHNC.wav' to 'Hindi' folder.
# Moved '2097_BM02OENC.wav' to 'English' folder.
# Moved '2097_BM02OHNC.wav' to 'Hindi' folder.
# Moved '2097_BT01OENC.wav' to 'English' folder.
# Moved '2097_BT01OHNC.wav' to 'Hindi' folder.
# Moved '2100_BD01OENC.wav' to 'English' folder.
# Moved '2100_BD01OHNC.wav' to 'Hindi' folder.
# Moved '2100_BH01OENC.wav' to 'English' folder.
# Moved '2100_BH01OHNC.wav' to 'Hindi' folder.
# Moved '2100_BM01OENC.wav' to 'English' folder.
# Moved '2100_BM01OHNC.wav' to 'Hindi' folder.
# Moved '2100_BM02OENC.wav' to 'English' folder.
# Moved '2100_BM02OHNC.wav' to 'Hindi' folder.
# Moved '2100_BT01OENC.wav' to 'English' folder.
# Moved '2100_BT01OHNC.wav' to 'Hindi' folder.
# Moved '2102_BD01OASC.wav' to 'Assamese' folder.
# Moved '2102_BD01OENC.wav' to 'English' folder.
# Moved '2102_BH01OASC.wav' to 'Assamese' folder.
# Moved '2102_BH01OENC.wav' to 'English' folder.
# Moved '2102_BM01OASC.wav' to 'Assamese' folder.
# Moved '2102_BM01OENC.wav' to 'English' folder.
# Moved '2102_BM02OASC.wav' to 'Assamese' folder.
# Moved '2102_BM02OENC.wav' to 'English' folder.
# Moved '2102_BT01OASC.wav' to 'Assamese' folder.
# Moved '2102_BT01OENC.wav' to 'English' folder.
# Moved '2103_BD01OENC.wav' to 'English' folder.
# Moved '2103_BD01OHNC.wav' to 'Hindi' folder.
# Moved '2103_BH01OENC.wav' to 'English' folder.
# Moved '2103_BH01OHNC.wav' to 'Hindi' folder.
# Moved '2103_BM01OENC.wav' to 'English' folder.
# Moved '2103_BM01OHNC.wav' to 'Hindi' folder.
# Moved '2103_BM02OENC.wav' to 'English' folder.
# Moved '2103_BM02OHNC.wav' to 'Hindi' folder.
# Moved '2103_BT01OENC.wav' to 'English' folder.
# Moved '2103_BT01OHNC.wav' to 'Hindi' folder.
# Audio file segregation complete.

# %% [markdown]
# Code to generate labels comparing one folder

# %%
import os

def collect_audio_files(audio_dir):
    """
    Recursively collect audio filenames and their speaker IDs
    based on the immediate subfolder under `audio_dir`.
    """
    audio_data = []

    for root, dirs, files in os.walk(audio_dir):
        for file in files:
            if file.endswith(('.wav', '.mp3', '.amr')):
                speaker_id = os.path.relpath(root, audio_dir).split(os.sep)[0]
                key = f"{speaker_id}@{file}"
                audio_data.append((speaker_id, key))

    return audio_data

def compare_speaker_ids(audio_dir, output_filename):
    """
    Compares speaker IDs based on folder names and writes pairwise labels.

    Args:
        audio_dir (str): Path to audio directory structured by speaker IDs.
        output_filename (str): Output file to write labels and file pairs.
    """
    audio_data = collect_audio_files(audio_dir)

    with open(output_filename, 'w') as outfile:
        for i in range(len(audio_data)):
            speaker_id1, key1 = audio_data[i]
            for j in range(len(audio_data)):
                speaker_id2, key2 = audio_data[j]

                label = 1 if speaker_id1 == speaker_id2 else 0
                outfile.write(f"{label} {key1} {key2}\n")

    print(f"Speaker ID comparison complete. Results saved to '{output_filename}'")

if __name__ == "__main__":
    audio_directory = input("Enter the directory containing the audio files: ")
    output_file = input("Enter the name for the output text file (e.g., comparison.txt): ")
    compare_speaker_ids(audio_directory, output_file)
# Out:
# Speaker ID comparison complete. Results saved to 'other_to_other.txt'

# %% [markdown]
# creating chunks of only 8 secs of the audio files without changing the speaker ID taking the reference of Voxceleb Dataset

# %%
import os
import wave
import contextlib
from pydub import AudioSegment

def split_wav_files(base_dir):
    chunk_base_dir = os.path.join(base_dir, "chunk")
    os.makedirs(chunk_base_dir, exist_ok=True)
    
    # Iterate through all label directories in the base directory
    for label in os.listdir(base_dir):
        label_path = os.path.join(base_dir, label)
        if not os.path.isdir(label_path) or label == "chunk":
            continue
        
        label_chunk_dir = os.path.join(chunk_base_dir, label)
        os.makedirs(label_chunk_dir, exist_ok=True)
        
        for filename in os.listdir(label_path):
            if filename.endswith(".wav"):
                file_path = os.path.join(label_path, filename)
                audio = AudioSegment.from_wav(file_path)
                duration_ms = len(audio)
                chunk_size = 8000  # 8 seconds in milliseconds
                
                # Split and save chunks
                for i, start in enumerate(range(0, duration_ms, chunk_size)):
                    end = min(start + chunk_size, duration_ms)
                    chunk = audio[start:end]
                    chunk_filename = f"{os.path.splitext(filename)[0]}_chunk{i+1}.wav"
                    chunk.export(os.path.join(label_chunk_dir, chunk_filename), format="wav")

if __name__ == "__main__":
    base_directory = "./TEST"  # Adjust if necessary
    split_wav_files(base_directory)
    print("creating chunks completed")

# %% [markdown]
# Comparing two Folders And generating labels

# %%
import os

def get_speaker_id(filename):
    """Extracts the speaker ID (first 4 digits before underscore) from filename."""
    return filename.split('_')[0]

def generate_labels(folder1, folder2, output_file='labels.txt'):
    files1 = [f for f in os.listdir(folder1) if f.endswith('.wav')]
    files2 = [f for f in os.listdir(folder2) if f.endswith('.wav')]

    with open(output_file, 'w') as out:
        for file1 in files1:
            speaker1 = get_speaker_id(file1)
            for file2 in files2:
                speaker2 = get_speaker_id(file2)
                label = 1 if speaker1 == speaker2 else 0
                out.write(f"{label} {file1} {file2}\n")

    print(f"[✓] Labels saved to {output_file}")

# Example usage
generate_labels('./english', './favourite_language', 'english_to_other.txt')
# Out:
# [✓] Labels saved to english_to_other.txt

# %% [markdown]
# Segregate Speakers according to Speaker ID

# %%
import os
import shutil

def get_speaker_id(filename):
    """Extract speaker ID (first 4 characters before underscore)."""
    return filename.split('_')[0]

def segregate_audio_by_speaker(source_dir, destination_dir):
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)

    for filename in os.listdir(source_dir):
        if filename.endswith('.wav'):
            speaker_id = get_speaker_id(filename)
            speaker_folder = os.path.join(destination_dir, speaker_id)

            if not os.path.exists(speaker_folder):
                os.makedirs(speaker_folder)

            src_path = os.path.join(source_dir, filename)
            dst_path = os.path.join(speaker_folder, filename)

            shutil.move(src_path, dst_path)

    print("[✓] Files segregated by speaker ID successfully.")

# Example usage
segregate_audio_by_speaker("./segregated/Other languages", "segregated_audio")
# Out:
# [✓] Files segregated by speaker ID successfully.

# %% [markdown]
# Folder to Foldder camparisio for english to Fav and fav to english

# %%
import os

def get_speaker_id(filename):
    """Extracts the speaker ID (first 4 characters before underscore) from filename."""
    return filename.split('_')[0]

def get_all_wav_files(root_folder):
    """Returns list of (speaker_id, full_path, relative_path) tuples for all .wav files in subdirectories."""
    wav_files = []
    for subdir, _, files in os.walk(root_folder):
        for file in files:
            if file.endswith('.wav'):
                full_path = os.path.join(subdir, file)
                rel_path = os.path.relpath(full_path)
                speaker_id = get_speaker_id(file)
                wav_files.append((speaker_id, file, rel_path))
    return wav_files

def generate_labels(folder1, folder2, output_file='labels.txt'):
    files1 = get_all_wav_files(folder1)
    files2 = get_all_wav_files(folder2)

    with open(output_file, 'w') as out:
        for spk1, file1, path1 in files1:
            for spk2, file2, path2 in files2:
                label = 1 if spk1 == spk2 else 0
                out.write(f"{label} {spk1}@{file1} {spk2}@{file2}\n")
                # Alternatively, use full paths:
                # out.write(f"{label} {path1} {path2}\n")

    print(f"[✓] Labels saved to {output_file}")

# Example usage
generate_labels('./english', './favourite_language', 'English_To_Others.txt')

# %% [markdown]
# Segregating chunked files

# %%
import os
import shutil

source_folder = './TEST'
english_folder = 'english'
favourite_language_folder = 'favourite_language'

# Create main destination folders if they don't exist
os.makedirs(english_folder, exist_ok=True)
os.makedirs(favourite_language_folder, exist_ok=True)

for speaker_id in os.listdir(source_folder):
    speaker_path = os.path.join(source_folder, speaker_id)
    print(f"Processing speaker folder: {speaker_path}")
    if os.path.isdir(speaker_path):
        # Create speaker ID subfolders in destination folders
        english_speaker_folder = os.path.join(english_folder, speaker_id)
        favourite_language_speaker_folder = os.path.join(favourite_language_folder, speaker_id)
        os.makedirs(english_speaker_folder, exist_ok=True)
        os.makedirs(favourite_language_speaker_folder, exist_ok=True)
        print(f"Created English speaker folder: {english_speaker_folder}")
        print(f"Created Favourite Language speaker folder: {favourite_language_speaker_folder}")

        for filename in os.listdir(speaker_path):
            if filename.endswith('.wav'):
                name_without_extension = filename[:-4]  # Remove .wav extension
                parts = name_without_extension.split('_')
                if len(parts) > 1:
                    code_part = parts[1]
                    if len(code_part) >= 2:
                        language_code = code_part[5:7]  # Extract last two characters as language code
                        source_file = os.path.join(speaker_path, filename)
                        print(f"Processing file: {source_file}, Language Code: {language_code}")

                        if language_code == 'EN':
                            destination_path = os.path.join(english_speaker_folder, filename)
                            shutil.copy(source_file, destination_path)
                            print(f"Copied to: {destination_path}")
                        else:
                            destination_path = os.path.join(favourite_language_speaker_folder, filename)
                            shutil.copy(source_file, destination_path)
                            print(f"Copied to: {destination_path}")
                    else:
                        print(f"Skipping file due to short code part in filename: {filename}")
                else:
                    print(f"Skipping file due to incorrect filename format: {filename}")
            else:
                print(f"Skipping non-WAV file: {filename}")
    else:
        print(f"Skipping non-directory item: {speaker_id}")

print("File segregation process completed (files copied).")
# Out:
# Processing speaker folder: ./TEST\1043
# Created English speaker folder: english\1043
# Created Favourite Language speaker folder: favourite_language\1043
# Processing file: ./TEST\1043\1043_BD01OENC.wav, Language Code: EN
# Copied to: english\1043\1043_BD01OENC.wav
# Processing file: ./TEST\1043\1043_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1043\1043_BD01OHNC.wav
# Processing file: ./TEST\1043\1043_BH01OENC.wav, Language Code: EN
# Copied to: english\1043\1043_BH01OENC.wav
# Processing file: ./TEST\1043\1043_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1043\1043_BH01OHNC.wav
# Processing file: ./TEST\1043\1043_BM01OENC.wav, Language Code: EN
# Copied to: english\1043\1043_BM01OENC.wav
# Processing file: ./TEST\1043\1043_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1043\1043_BM01OHNC.wav
# Processing file: ./TEST\1043\1043_BM02OENC.wav, Language Code: EN
# Copied to: english\1043\1043_BM02OENC.wav
# Processing file: ./TEST\1043\1043_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1043\1043_BM02OHNC.wav
# Processing file: ./TEST\1043\1043_BT01OENC.wav, Language Code: EN
# Copied to: english\1043\1043_BT01OENC.wav
# Processing file: ./TEST\1043\1043_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1043\1043_BT01OHNC.wav
# Processing speaker folder: ./TEST\1066
# Created English speaker folder: english\1066
# Created Favourite Language speaker folder: favourite_language\1066
# Processing file: ./TEST\1066\1066_BD01OENC.wav, Language Code: EN
# Copied to: english\1066\1066_BD01OENC.wav
# Processing file: ./TEST\1066\1066_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\
# Processing file: ./TEST\1068\1068_BM02OENC.wav, Language Code: EN
# Copied to: english\1068\1068_BM02OENC.wav
# Processing file: ./TEST\1068\1068_BM02OORC.wav, Language Code: OR
# Copied to: favourite_language\1068\1068_BM02OORC.wav
# Processing file: ./TEST\1068\1068_BT01OENC.wav, Language Code: EN
# Copied to: english\1068\1068_BT01OENC.wav
# Processing file: ./TEST\1068\1068_BT01OORC.wav, Language Code: OR
# Copied to: favourite_language\1068\1068_BT01OORC.wav
# Processing speaker folder: ./TEST\1069
# Created English speaker folder: english\1069
# Created Favourite Language speaker folder: favourite_language\1069
# Processing file: ./TEST\1069\1069_BD01OENC.wav, Language Code: EN
# Copied to: english\1069\1069_BD01OENC.wav
# Processing file: ./TEST\1069\1069_BD01OORC.wav, Language Code: OR
# Copied to: favourite_language\1069\1069_BD01OORC.wav
# Processing file: ./TEST\1069\1069_BH01OENC.wav, Language Code: EN
# Copied to: english\1069\1069_BH01OENC.wav
# Processing file: ./TEST\1069\1069_BH01OORC.wav, Language Code: OR
# Copied to: favourite_language\1069\1069_BH01OORC.wav
# Processing file: ./TEST\1069\1069_BM01OENC.wav, Language Code: EN
# Copied to: english\1069\1069_BM01OENC.wav
# Processing file: ./TEST\1069\1069_BM01OORC.wav, Language Code: OR
# Copied to: favourite_language\1069\1069_BM01OORC.wav
# Processing file: ./TEST\1069\1069_BM02OENC.wav, Language Code: EN
# Copied to: english\1069\1069_BM02OENC.wav
# Processing file: ./TEST\1069\1069_BM02OORC.wav, Language Code: OR
# Copied to: favourite_language\1069\1069_BM02OORC.wav
# Processing file: ./TEST\1069\1069_BT01OENC.wav, Language Code: EN
# Copied to: english\1069\1069_BT01OENC.wav
# Processing file: ./TEST\1069\1069_BT01OORC.wav, Language Code: OR
# Copied to: favourite_language\1069\1069_BT01OORC.wav
# Processing speaker folder: ./TEST\1070
# Created English speaker folder: english\1070
# Created Favourite Language speaker folder: favourite_language\1070
# Processing file: ./TEST\1070\1070_BD01OENC.wav, Language Code: EN
# Copied to: english\1070\1070_BD01OENC.wav
# Processing file: ./TEST\1070\1070_BD01OORC.wav, Language Code: OR
# Copied to: favourite_language\1070\1070_BD01OORC.wav
# Processing file: ./TEST\1070\1070_BH01OENC.wav, Language Code: EN
# Copied to: english\1070\1070_BH01OENC.wav
# Processing file: ./TEST\1070\1070_BH01OORC.wav, Language Code: OR
# Copied to: favourite_language\1070\1070_BH01OORC.wav
# Processing file: ./TEST\1070\1070_BM01OENC.wav, Language Code: EN
# Copied to: english\1070\1070_BM01OENC.wav
# Processing file: ./TEST\1070\1070_BM01OORC.wav, Language Code: OR
# Copied to: favourite_language\1070\1070_BM01OORC.wav
# Processing file: ./TEST\1070\1070_BM02OENC.wav, Language Code: EN
# Copied to: english\1070\1070_BM02OENC.wav
# Processing file: ./TEST\1070\1070_BM02OORC.wav, Language Code: OR
# Copied to: favourite_language\1070\1070_BM02OORC.wav
# Processing file: ./TEST\1070\1070_BT01OENC.wav, Language Code: EN
# Copied to: english\1070\1070_BT01OENC.wav
# Processing file: ./TEST\1070\1070_BT01OORC.wav, Language Code: OR
# Copied to: favourite_language\1070\1070_BT01OORC.wav
# Processing speaker folder: ./TEST\1071
# Created English speaker folder: english\1071
# Created Favourite Language speaker folder: favourite_language\1071
# Processing file: ./TEST\1071\1071_BD01OENC.wav, Language Code: EN
# Copied to: english\1071\1071_BD01OENC.wav
# Processing file: ./TEST\1071\1071_BD01OMLC.wav, Language Code: ML
# Copied to: favourite_language\1071\1071_BD01OMLC.wav
# Processing file: ./TEST\1071\1071_BH01OENC.wav, Language Code: EN
# Copied to: english\1071\1071_BH01OENC.wav
# Processing file: ./TEST\1071\1071_BH01OMLC.wav, Language Code: ML
# Copied to: favourite_language\1071\1071_BH01OMLC.wav
# Processing file: ./TEST\1071\1071_BM01OENC.wav, Language Code: EN
# Copied to: english\1071\1071_BM01OENC.wav
# Processing file: ./TEST\1071\1071_BM01OMLC.wav, Language Code: ML
# Copied to: favourite_language\1071\1071_BM01OMLC.wav
# Processing file: ./TEST\1071\1071_BM02OENC.wav, Language Code: EN
# Copied to: english\1071\1071_BM02OENC.wav
# Processing file: ./TEST\1071\1071_BM02OMLC.wav, Language Code: ML
# Copied to: favourite_language\1071\1071_BM02OMLC.wav
# Processing file: ./TEST\1071\1071_BT01OENC.wav, Language Code: EN
# Copied to: english\1071\1071_BT01OENC.wav
# Processing file: ./TEST\1071\1071_BT01OMLC.wav, Language Code: ML
# Copied to: favourite_language\1071\1071_BT01OMLC.wav
# Processing speaker folder: ./TEST\1072
# Created English speaker folder: english\1072
# Created Favourite Language speaker folder: favourite_language\1072
# Processing file: ./TEST\1072\1072_BD01OENC.wav, Language Code: EN
# Copied to: english\1072\1072_BD01OENC.wav
# Processing file: ./TEST\1072\1072_BD01OGJC.wav, Language Code: GJ
# Copied to: favourite_language\1072\1072_BD01OGJC.wav
# Processing file: ./TEST\1072\1072_BH01OENC.wav, Language Code: EN
# Copied to: english\1072\1072_BH01OENC.wav
# Processing file: ./TEST\1072\1072_BH01OGJC.wav, Language Code: GJ
# Copied to: favourite_language\1072\1072_BH01OGJC.wav
# Processing file: ./TEST\1072\1072_BM01OENC.wav, Language Code: EN
# Copied to: english\1072\1072_BM01OENC.wav
# Processing file: ./TEST\1072\1072_BM01OGJC.wav, Language Code: GJ
# Copied to: favourite_language\1072\1072_BM01OGJC.wav
# Processing file: ./TEST\1072\1072_BM02OENC.wav, Language Code: EN
# Copied to: english\1072\1072_BM02OENC.wav
# Processing file: ./TEST\1072\1072_BM02OGJC.wav, Language Code: GJ
# Copied to: favourite_language\1072\1072_BM02OGJC.wav
# Processing file: ./TEST\1072\1072_BT01OENC.wav, Language Code: EN
# Copied to: english\1072\1072_BT01OENC.wav
# Processing file: ./TEST\1072\1072_BT01OGJC.wav, Language Code: GJ
# Copied to: favourite_language\1072\1072_BT01OGJC.wav
# Processing speaker folder: ./TEST\1073
# Created English speaker folder: english\1073
# Created Favourite Language speaker folder: favourite_language\1073
# Processing file: ./TEST\1073\1073_BD01OENC.wav, Language Code: EN
# Copied to: english\1073\1073_BD01OENC.wav
# Processing file: ./TEST\1073\1073_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1073\1073_BD01OHNC.wav
# Processing file: ./TEST\1073\1073_BH01OENC.wav, Language Code: EN
# Copied to: english\1073\1073_BH01OENC.wav
# Processing file: ./TEST\1073\1073_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1073\1073_BH01OHNC.wav
# Processing file: ./TEST\1073\1073_BM01OENC.wav, Language Code: EN
# Copied to: english\1073\1073_BM01OENC.wav
# Processing file: ./TEST\1073\1073_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1073\1073_BM01OHNC.wav
# Processing file: ./TEST\1073\1073_BM02OENC.wav, Language Code: EN
# Copied to: english\1073\1073_BM02OENC.wav
# Processing file: ./TEST\1073\1073_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1073\1073_BM02OHNC.wav
# Processing file: ./TEST\1073\1073_BT01OENC.wav, Language Code: EN
# Copied to: english\1073\1073_BT01OENC.wav
# Processing file: ./TEST\1073\1073_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1073\1073_BT01OHNC.wav
# Processing speaker folder: ./TEST\1074
# Created English speaker folder: english\1074
# Created Favourite Language speaker folder: favourite_language\1074
# Processing file: ./TEST\1074\1074_BD01OENC.wav, Language Code: EN
# Copied to: english\1074\1074_BD01OENC.wav
# Processing file: ./TEST\1074\1074_BD01OORC.wav, Language Code: OR
# Copied to: favourite_language\1074\1074_BD01OORC.wav
# Processing file: ./TEST\1074\1074_BH01OENC.wav, Language Code: EN
# Copied to: english\1074\1074_BH01OENC.wav
# Processing file: ./TEST\1074\1074_BH01OORC.wav, Language Code: OR
# Copied to: favourite_language\1074\1074_BH01OORC.wav
# Processing file: ./TEST\1074\1074_BM01OENC.wav, Language Code: EN
# Copied to: english\1074\1074_BM01OENC.wav
# Processing file: ./TEST\1074\1074_BM01OORC.wav, Language Code: OR
# Copied to: favourite_language\1074\1074_BM01OORC.wav
# Processing file: ./TEST\1074\1074_BM02OENC.wav, Language Code: EN
# Copied to: english\1074\1074_BM02OENC.wav
# Processing file: ./TEST\1074\1074_BM02OORC.wav, Language Code: OR
# Copied to: favourite_language\1074\1074_BM02OORC.wav
# Processing file: ./TEST\1074\1074_BT01OENC.wav, Language Code: EN
# Copied to: english\1074\1074_BT01OENC.wav
# Processing file: ./TEST\1074\1074_BT01OORC.wav, Language Code: OR
# Copied to: favourite_language\1074\1074_BT01OORC.wav
# Processing speaker folder: ./TEST\1075
# Created English speaker folder: english\1075
# Created Favourite Language speaker folder: favourite_language\1075
# Processing file: ./TEST\1075\1075_BD01OENC.wav, Language Code: EN
# Copied to: english\1075\1075_BD01OENC.wav
# Processing file: ./TEST\1075\1075_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1075\1075_BD01OHNC.wav
# Processing file: ./TEST\1075\1075_BH01OENC.wav, Language Code: EN
# Copied to: english\1075\1075_BH01OENC.wav
# Processing file: ./TEST\1075\1075_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1075\1075_BH01OHNC.wav
# Processing file: ./TEST\1075\1075_BM01OENC.wav, Language Code: EN
# Copied to: english\1075\1075_BM01OENC.wav
# Processing file: ./TEST\1075\1075_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1075\1075_BM01OHNC.wav
# Processing file: ./TEST\1075\1075_BM02OENC.wav, Language Code: EN
# Copied to: english\1075\1075_BM02OENC.wav
# Processing file: ./TEST\1075\1075_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1075\1075_BM02OHNC.wav
# Processing file: ./TEST\1075\1075_BT01OENC.wav, Language Code: EN
# Copied to: english\1075\1075_BT01OENC.wav
# Processing file: ./TEST\1075\1075_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1075\1075_BT01OHNC.wav
# Processing speaker folder: ./TEST\1076
# Created English speaker folder: english\1076
# Created Favourite Language speaker folder: favourite_language\1076
# Processing file: ./TEST\1076\1076_BD01OENC.wav, Language Code: EN
# Copied to: english\1076\1076_BD01OENC.wav
# Processing file: ./TEST\1076\1076_BD01OMLC.wav, Language Code: ML
# Copied to: favourite_language\1076\1076_BD01OMLC.wav
# Processing file: ./TEST\1076\1076_BH01OENC.wav, Language Code: EN
# Copied to: english\1076\1076_BH01OENC.wav
# Processing file: ./TEST\1076\1076_BH01OMLC.wav, Language Code: ML
# Copied to: favourite_language\1076\1076_BH01OMLC.wav
# Processing file: ./TEST\1076\1076_BM01OENC.wav, Language Code: EN
# Copied to: english\1076\1076_BM01OENC.wav
# Processing file: ./TEST\1076\1076_BM01OMLC.wav, Language Code: ML
# Copied to: favourite_language\1076\1076_BM01OMLC.wav
# Processing file: ./TEST\1076\1076_BM02OENC.wav, Language Code: EN
# Copied to: english\1076\1076_BM02OENC.wav
# Processing file: ./TEST\1076\1076_BM02OMLC.wav, Language Code: ML
# Copied to: favourite_language\1076\1076_BM02OMLC.wav
# Processing file: ./TEST\1076\1076_BT01OENC.wav, Language Code: EN
# Copied to: english\1076\1076_BT01OENC.wav
# Processing file: ./TEST\1076\1076_BT01OMLC.wav, Language Code: ML
# Copied to: favourite_language\1076\1076_BT01OMLC.wav
# Processing speaker folder: ./TEST\1077
# Created English speaker folder: english\1077
# Created Favourite Language speaker folder: favourite_language\1077
# Processing file: ./TEST\1077\1077_BD01OENC.wav, Language Code: EN
# Copied to: english\1077\1077_BD01OENC.wav
# Processing file: ./TEST\1077\1077_BD01OORC.wav, Language Code: OR
# Copied to: favourite_language\1077\1077_BD01OORC.wav
# Processing file: ./TEST\1077\1077_BH01OENC.wav, Language Code: EN
# Copied to: english\1077\1077_BH01OENC.wav
# Processing file: ./TEST\1077\1077_BH01OORC.wav, Language Code: OR
# Copied to: favourite_language\1077\1077_BH01OORC.wav
# Processing file: ./TEST\1077\1077_BM01OENC.wav, Language Code: EN
# Copied to: english\1077\1077_BM01OENC.wav
# Processing file: ./TEST\1077\1077_BM01OORC.wav, Language Code: OR
# Copied to: favourite_language\1077\1077_BM01OORC.wav
# Processing file: ./TEST\1077\1077_BM02OENC.wav, Language Code: EN
# Copied to: english\1077\1077_BM02OENC.wav
# Processing file: ./TEST\1077\1077_BM02OORC.wav, Language Code: OR
# Copied to: favourite_language\1077\1077_BM02OORC.wav
# Processing file: ./TEST\1077\1077_BT01OENC.wav, Language Code: EN
# Copied to: english\1077\1077_BT01OENC.wav
# Processing file: ./TEST\1077\1077_BT01OORC.wav, Language Code: OR
# Copied to: favourite_language\1077\1077_BT01OORC.wav
# Processing speaker folder: ./TEST\1078
# Created English speaker folder: english\1078
# Created Favourite Language speaker folder: favourite_language\1078
# Processing file: ./TEST\1078\1078_BD01OENC.wav, Language Code: EN
# Copied to: english\1078\1078_BD01OENC.wav
# Processing file: ./TEST\1078\1078_BD01OKNC.wav, Language Code: KN
# Copied to: favourite_language\1078\1078_BD01OKNC.wav
# Processing file: ./TEST\1078\1078_BH01OENC.wav, Language Code: EN
# Copied to: english\1078\1078_BH01OENC.wav
# Processing file: ./TEST\1078\1078_BH01OKNC.wav, Language Code: KN
# Copied to: favourite_language\1078\1078_BH01OKNC.wav
# Processing file: ./TEST\1078\1078_BM01OENC.wav, Language Code: EN
# Copied to: english\1078\1078_BM01OENC.wav
# Processing file: ./TEST\1078\1078_BM01OKNC.wav, Language Code: KN
# Copied to: favourite_language\1078\1078_BM01OKNC.wav
# Processing file: ./TEST\1078\1078_BM02OENC.wav, Language Code: EN
# Copied to: english\1078\1078_BM02OENC.wav
# Processing file: ./TEST\1078\1078_BM02OKNC.wav, Language Code: KN
# Copied to: favourite_language\1078\1078_BM02OKNC.wav
# Processing file: ./TEST\1078\1078_BT01OENC.wav, Language Code: EN
# Copied to: english\1078\1078_BT01OENC.wav
# Processing file: ./TEST\1078\1078_BT01OKNC.wav, Language Code: KN
# Copied to: favourite_language\1078\1078_BT01OKNC.wav
# Processing speaker folder: ./TEST\1079
# Created English speaker folder: english\1079
# Created Favourite Language speaker folder: favourite_language\1079
# Processing file: ./TEST\1079\1079_BD01OENC.wav, Language Code: EN
# Copied to: english\1079\1079_BD01OENC.wav
# Processing file: ./TEST\1079\1079_BD01OORC.wav, Language Code: OR
# Copied to: favourite_language\1079\1079_BD01OORC.wav
# Processing file: ./TEST\1079\1079_BH01OENC.wav, Language Code: EN
# Copied to: english\1079\1079_BH01OENC.wav
# Processing file: ./TEST\1079\1079_BH01OORC.wav, Language Code: OR
# Copied to: favourite_language\1079\1079_BH01OORC.wav
# Processing file: ./TEST\1079\1079_BM01OENC.wav, Language Code: EN
# Copied to: english\1079\1079_BM01OENC.wav
# Processing file: ./TEST\1079\1079_BM01OORC.wav, Language Code: OR
# Copied to: favourite_language\1079\1079_BM01OORC.wav
# Processing file: ./TEST\1079\1079_BM02OENC.wav, Language Code: EN
# Copied to: english\1079\1079_BM02OENC.wav
# Processing file: ./TEST\1079\1079_BM02OORC.wav, Language Code: OR
# Copied to: favourite_language\1079\1079_BM02OORC.wav
# Processing file: ./TEST\1079\1079_BT01OENC.wav, Language Code: EN
# Copied to: english\1079\1079_BT01OENC.wav
# Processing file: ./TEST\1079\1079_BT01OORC.wav, Language Code: OR
# Copied to: favourite_language\1079\1079_BT01OORC.wav
# Processing speaker folder: ./TEST\1080
# Created English speaker folder: english\1080
# Created Favourite Language speaker folder: favourite_language\1080
# Processing file: ./TEST\1080\1080_BD01OENC.wav, Language Code: EN
# Copied to: english\1080\1080_BD01OENC.wav
# Processing file: ./TEST\1080\1080_BD01OTMC.wav, Language Code: TM
# Copied to: favourite_language\1080\1080_BD01OTMC.wav
# Processing file: ./TEST\1080\1080_BH01OENC.wav, Language Code: EN
# Copied to: english\1080\1080_BH01OENC.wav
# Processing file: ./TEST\1080\1080_BH01OTMC.wav, Language Code: TM
# Copied to: favourite_language\1080\1080_BH01OTMC.wav
# Processing file: ./TEST\1080\1080_BM01OENC.wav, Language Code: EN
# Copied to: english\1080\1080_BM01OENC.wav
# Processing file: ./TEST\1080\1080_BM01OTMC.wav, Language Code: TM
# Copied to: favourite_language\1080\1080_BM01OTMC.wav
# Processing file: ./TEST\1080\1080_BM02OENC.wav, Language Code: EN
# Copied to: english\1080\1080_BM02OENC.wav
# Processing file: ./TEST\1080\1080_BM02OTMC.wav, Language Code: TM
# Copied to: favourite_language\1080\1080_BM02OTMC.wav
# Processing file: ./TEST\1080\1080_BT01OENC.wav, Language Code: EN
# Copied to: english\1080\1080_BT01OENC.wav
# Processing file: ./TEST\1080\1080_BT01OTMC.wav, Language Code: TM
# Copied to: favourite_language\1080\1080_BT01OTMC.wav
# Processing speaker folder: ./TEST\1081
# Created English speaker folder: english\1081
# Created Favourite Language speaker folder: favourite_language\1081
# Processing file: ./TEST\1081\1081_BD01OENC.wav, Language Code: EN
# Copied to: english\1081\1081_BD01OENC.wav
# Processing file: ./TEST\1081\1081_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1081\1081_BD01OHNC.wav
# Processing file: ./TEST\1081\1081_BH01OENC.wav, Language Code: EN
# Copied to: english\1081\1081_BH01OENC.wav
# Processing file: ./TEST\1081\1081_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1081\1081_BH01OHNC.wav
# Processing file: ./TEST\1081\1081_BM01OENC.wav, Language Code: EN
# Copied to: english\1081\1081_BM01OENC.wav
# Processing file: ./TEST\1081\1081_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1081\1081_BM01OHNC.wav
# Processing file: ./TEST\1081\1081_BM02OENC.wav, Language Code: EN
# Copied to: english\1081\1081_BM02OENC.wav
# Processing file: ./TEST\1081\1081_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1081\1081_BM02OHNC.wav
# Processing file: ./TEST\1081\1081_BT01OENC.wav, Language Code: EN
# Copied to: english\1081\1081_BT01OENC.wav
# Processing file: ./TEST\1081\1081_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1081\1081_BT01OHNC.wav
# Processing speaker folder: ./TEST\1082
# Created English speaker folder: english\1082
# Created Favourite Language speaker folder: favourite_language\1082
# Processing file: ./TEST\1082\1082_BD01OASC.wav, Language Code: AS
# Copied to: favourite_language\1082\1082_BD01OASC.wav
# Processing file: ./TEST\1082\1082_BD01OENC.wav, Language Code: EN
# Copied to: english\1082\1082_BD01OENC.wav
# Processing file: ./TEST\1082\1082_BH01OASC.wav, Language Code: AS
# Copied to: favourite_language\1082\1082_BH01OASC.wav
# Processing file: ./TEST\1082\1082_BH01OENC.wav, Language Code: EN
# Copied to: english\1082\1082_BH01OENC.wav
# Processing file: ./TEST\1082\1082_BM01OASC.wav, Language Code: AS
# Copied to: favourite_language\1082\1082_BM01OASC.wav
# Processing file: ./TEST\1082\1082_BM01OENC.wav, Language Code: EN
# Copied to: english\1082\1082_BM01OENC.wav
# Processing file: ./TEST\1082\1082_BM02OASC.wav, Language Code: AS
# Copied to: favourite_language\1082\1082_BM02OASC.wav
# Processing file: ./TEST\1082\1082_BM02OENC.wav, Language Code: EN
# Copied to: english\1082\1082_BM02OENC.wav
# Processing file: ./TEST\1082\1082_BT01OASC.wav, Language Code: AS
# Copied to: favourite_language\1082\1082_BT01OASC.wav
# Processing file: ./TEST\1082\1082_BT01OENC.wav, Language Code: EN
# Copied to: english\1082\1082_BT01OENC.wav
# Processing speaker folder: ./TEST\1084
# Created English speaker folder: english\1084
# Created Favourite Language speaker folder: favourite_language\1084
# Processing file: ./TEST\1084\1084_BD01OENC.wav, Language Code: EN
# Copied to: english\1084\1084_BD01OENC.wav
# Processing file: ./TEST\1084\1084_BD01OORC.wav, Language Code: OR
# Copied to: favourite_language\1084\1084_BD01OORC.wav
# Processing file: ./TEST\1084\1084_BH01OENC.wav, Language Code: EN
# Copied to: english\1084\1084_BH01OENC.wav
# Processing file: ./TEST\1084\1084_BH01OORC.wav, Language Code: OR
# Copied to: favourite_language\1084\1084_BH01OORC.wav
# Processing file: ./TEST\1084\1084_BM01OENC.wav, Language Code: EN
# Copied to: english\1084\1084_BM01OENC.wav
# Processing file: ./TEST\1084\1084_BM01OORC.wav, Language Code: OR
# Copied to: favourite_language\1084\1084_BM01OORC.wav
# Processing file: ./TEST\1084\1084_BM02OENC.wav, Language Code: EN
# Copied to: english\1084\1084_BM02OENC.wav
# Processing file: ./TEST\1084\1084_BM02OORC.wav, Language Code: OR
# Copied to: favourite_language\1084\1084_BM02OORC.wav
# Processing file: ./TEST\1084\1084_BT01OENC.wav, Language Code: EN
# Copied to: english\1084\1084_BT01OENC.wav
# Processing file: ./TEST\1084\1084_BT01OORC.wav, Language Code: OR
# Copied to: favourite_language\1084\1084_BT01OORC.wav
# Processing speaker folder: ./TEST\1085
# Created English speaker folder: english\1085
# Created Favourite Language speaker folder: favourite_language\1085
# Processing file: ./TEST\1085\1085_BD01OBNC.wav, Language Code: BN
# Copied to: favourite_language\1085\1085_BD01OBNC.wav
# Processing file: ./TEST\1085\1085_BD01OENC.wav, Language Code: EN
# Copied to: english\1085\1085_BD01OENC.wav
# Processing file: ./TEST\1085\1085_BH01OBNC.wav, Language Code: BN
# Copied to: favourite_language\1085\1085_BH01OBNC.wav
# Processing file: ./TEST\1085\1085_BH01OENC.wav, Language Code: EN
# Copied to: english\1085\1085_BH01OENC.wav
# Processing file: ./TEST\1085\1085_BM01OBNC.wav, Language Code: BN
# Copied to: favourite_language\1085\1085_BM01OBNC.wav
# Processing file: ./TEST\1085\1085_BM01OENC.wav, Language Code: EN
# Copied to: english\1085\1085_BM01OENC.wav
# Processing file: ./TEST\1085\1085_BM02OBNC.wav, Language Code: BN
# Copied to: favourite_language\1085\1085_BM02OBNC.wav
# Processing file: ./TEST\1085\1085_BM02OENC.wav, Language Code: EN
# Copied to: english\1085\1085_BM02OENC.wav
# Processing file: ./TEST\1085\1085_BT01OBNC.wav, Language Code: BN
# Copied to: favourite_language\1085\1085_BT01OBNC.wav
# Processing file: ./TEST\1085\1085_BT01OENC.wav, Language Code: EN
# Copied to: english\1085\1085_BT01OENC.wav
# Processing speaker folder: ./TEST\1086
# Created English speaker folder: english\1086
# Created Favourite Language speaker folder: favourite_language\1086
# Processing file: ./TEST\1086\1086_BD01OENC.wav, Language Code: EN
# Copied to: english\1086\1086_BD01OENC.wav
# Processing file: ./TEST\1086\1086_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\
BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1088\1088_BT01OHNC.wav
# Processing speaker folder: ./TEST\1089
# Created English speaker folder: english\1089
# Created Favourite Language speaker folder: favourite_language\1089
# Processing file: ./TEST\1089\1089_BD01OENC.wav, Language Code: EN
# Copied to: english\1089\1089_BD01OENC.wav
# Processing file: ./TEST\1089\1089_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1089\1089_BD01OHNC.wav
# Processing file: ./TEST\1089\1089_BH01OENC.wav, Language Code: EN
# Copied to: english\1089\1089_BH01OENC.wav
# Processing file: ./TEST\1089\1089_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1089\1089_BH01OHNC.wav
# Processing file: ./TEST\1089\1089_BM01OENC.wav, Language Code: EN
# Copied to: english\1089\1089_BM01OENC.wav
# Processing file: ./TEST\1089\1089_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1089\1089_BM01OHNC.wav
# Processing file: ./TEST\1089\1089_BM02OENC.wav, Language Code: EN
# Copied to: english\1089\1089_BM02OENC.wav
# Processing file: ./TEST\1089\1089_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1089\1089_BM02OHNC.wav
# Processing file: ./TEST\1089\1089_BT01OENC.wav, Language Code: EN
# Copied to: english\1089\1089_BT01OENC.wav
# Processing file: ./TEST\1089\1089_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1089\1089_BT01OHNC.wav
# Processing speaker folder: ./TEST\1090
# Created English speaker folder: english\1090
# Created Favourite Language speaker folder: favourite_language\1090
# Processing file: ./TEST\1090\1090_BD01OENC.wav, Language Code: EN
# Copied to: english\1090\1090_BD01OENC.wav
# Processing file: ./TEST\1090\1090_BD01OMRC.wav, Language Code: MR
# Copied to: favourite_language\1090\1090_BD01OMRC.wav
# Processing file: ./TEST\1090\1090_BH01OENC.wav, Language Code: EN
# Copied to: english\1090\1090_BH01OENC.wav
# Processing file: ./TEST\1090\1090_BH01OMRC.wav, Language Code: MR
# Copied to: favourite_language\1090\1090_BH01OMRC.wav
# Processing file: ./TEST\1090\1090_BM01OENC.wav, Language Code: EN
# Copied to: english\1090\1090_BM01OENC.wav
# Processing file: ./TEST\1090\1090_BM01OMRC.wav, Language Code: MR
# Copied to: favourite_language\1090\1090_BM01OMRC.wav
# Processing file: ./TEST\1090\1090_BM02OENC.wav, Language Code: EN
# Copied to: english\1090\1090_BM02OENC.wav
# Processing file: ./TEST\1090\1090_BM02OMRC.wav, Language Code: MR
# Copied to: favourite_language\1090\1090_BM02OMRC.wav
# Processing file: ./TEST\1090\1090_BT01OENC.wav, Language Code: EN
# Copied to: english\1090\1090_BT01OENC.wav
# Processing file: ./TEST\1090\1090_BT01OMRC.wav, Language Code: MR
# Copied to: favourite_language\1090\1090_BT01OMRC.wav
# Processing speaker folder: ./TEST\1091
# Created English speaker folder: english\1091
# Created Favourite Language speaker folder: favourite_language\1091
# Processing file: ./TEST\1091\1091_BD01OENC.wav, Language Code: EN
# Copied to: english\1091\1091_BD01OENC.wav
# Processing file: ./TEST\1091\1091_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1091\1091_BD01OHNC.wav
# Processing file: ./TEST\1091\1091_BH01OENC.wav, Language Code: EN
# Copied to: english\1091\1091_BH01OENC.wav
# Processing file: ./TEST\1091\1091_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1091\1091_BH01OHNC.wav
# Processing file: ./TEST\1091\1091_BM01OENC.wav, Language Code: EN
# Copied to: english\1091\1091_BM01OENC.wav
# Processing file: ./TEST\1091\1091_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1091\1091_BM01OHNC.wav
# Processing file: ./TEST\1091\1091_BM02OENC.wav, Language Code: EN
# Copied to: english\1091\1091_BM02OENC.wav
# Processing file: ./TEST\1091\1091_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1091\1091_BM02OHNC.wav
# Processing file: ./TEST\1091\1091_BT01OENC.wav, Language Code: EN
# Copied to: english\1091\1091_BT01OENC.wav
# Processing file: ./TEST\1091\1091_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1091\1091_BT01OHNC.wav
# Processing speaker folder: ./TEST\1092
# Created English speaker folder: english\1092
# Created Favourite Language speaker folder: favourite_language\1092
# Processing file: ./TEST\1092\1092_BD01OENC.wav, Language Code: EN
# Copied to: english\1092\1092_BD01OENC.wav
# Processing file: ./TEST\1092\1092_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1092\1092_BD01OHNC.wav
# Processing file: ./TEST\1092\1092_BH01OENC.wav, Language Code: EN
# Copied to: english\1092\1092_BH01OENC.wav
# Processing file: ./TEST\1092\1092_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1092\1092_BH01OHNC.wav
# Processing file: ./TEST\1092\1092_BM01OENC.wav, Language Code: EN
# Copied to: english\1092\1092_BM01OENC.wav
# Processing file: ./TEST\1092\1092_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1092\1092_BM01OHNC.wav
# Processing file: ./TEST\1092\1092_BM02OENC.wav, Language Code: EN
# Copied to: english\1092\1092_BM02OENC.wav
# Processing file: ./TEST\1092\1092_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1092\1092_BM02OHNC.wav
# Processing file: ./TEST\1092\1092_BT01OENC.wav, Language Code: EN
# Copied to: english\1092\1092_BT01OENC.wav
# Processing file: ./TEST\1092\1092_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1092\1092_BT01OHNC.wav
# Processing speaker folder: ./TEST\1093
# Created English speaker folder: english\1093
# Created Favourite Language speaker folder: favourite_language\1093
# Processing file: ./TEST\1093\1093_BD01OENC.wav, Language Code: EN
# Copied to: english\1093\1093_BD01OENC.wav
# Processing file: ./TEST\1093\1093_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1093\1093_BD01OHNC.wav
# Processing file: ./TEST\1093\1093_BH01OENC.wav, Language Code: EN
# Copied to: english\1093\1093_BH01OENC.wav
# Processing file: ./TEST\1093\1093_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1093\1093_BH01OHNC.wav
# Processing file: ./TEST\1093\1093_BM01OENC.wav, Language Code: EN
# Copied to: english\1093\1093_BM01OENC.wav
# Processing file: ./TEST\1093\1093_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1093\1093_BM01OHNC.wav
# Processing file: ./TEST\1093\1093_BM02OENC.wav, Language Code: EN
# Copied to: english\1093\1093_BM02OENC.wav
# Processing file: ./TEST\1093\1093_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1093\1093_BM02OHNC.wav
# Processing file: ./TEST\1093\1093_BT01OENC.wav, Language Code: EN
# Copied to: english\1093\1093_BT01OENC.wav
# Processing file: ./TEST\1093\1093_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1093\1093_BT01OHNC.wav
# Processing speaker folder: ./TEST\1094
# Created English speaker folder: english\1094
# Created Favourite Language speaker folder: favourite_language\1094
# Processing file: ./TEST\1094\1094_BD01OENC.wav, Language Code: EN
# Copied to: english\1094\1094_BD01OENC.wav
# Processing file: ./TEST\1094\1094_BD01OKNC.wav, Language Code: KN
# Copied to: favourite_language\1094\1094_BD01OKNC.wav
# Processing file: ./TEST\1094\1094_BH01OENC.wav, Language Code: EN
# Copied to: english\1094\1094_BH01OENC.wav
# Processing file: ./TEST\1094\1094_BH01OKNC.wav, Language Code: KN
# Copied to: favourite_language\1094\1094_BH01OKNC.wav
# Processing file: ./TEST\1094\1094_BM01OENC.wav, Language Code: EN
# Copied to: english\1094\1094_BM01OENC.wav
# Processing file: ./TEST\1094\1094_BM01OKNC.wav, Language Code: KN
# Copied to: favourite_language\1094\1094_BM01OKNC.wav
# Processing file: ./TEST\1094\1094_BM02OENC.wav, Language Code: EN
# Copied to: english\1094\1094_BM02OENC.wav
# Processing file: ./TEST\1094\1094_BM02OKNC.wav, Language Code: KN
# Copied to: favourite_language\1094\1094_BM02OKNC.wav
# Processing file: ./TEST\1094\1094_BT01OENC.wav, Language Code: EN
# Copied to: english\1094\1094_BT01OENC.wav
# Processing file: ./TEST\1094\1094_BT01OKNC.wav, Language Code: KN
# Copied to: favourite_language\1094\1094_BT01OKNC.wav
# Processing speaker folder: ./TEST\1095
# Created English speaker folder: english\1095
# Created Favourite Language speaker folder: favourite_language\1095
# Processing file: ./TEST\1095\1095_BD01OENC.wav, Language Code: EN
# Copied to: english\1095\1095_BD01OENC.wav
# Processing file: ./TEST\1095\1095_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1095\1095_BD01OHNC.wav
# Processing file: ./TEST\1095\1095_BH01OENC.wav, Language Code: EN
# Copied to: english\1095\1095_BH01OENC.wav
# Processing file: ./TEST\1095\1095_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1095\1095_BH01OHNC.wav
# Processing file: ./TEST\1095\1095_BM01OENC.wav, Language Code: EN
# Copied to: english\1095\1095_BM01OENC.wav
# Processing file: ./TEST\1095\1095_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1095\1095_BM01OHNC.wav
# Processing file: ./TEST\1095\1095_BM02OENC.wav, Language Code: EN
# Copied to: english\1095\1095_BM02OENC.wav
# Processing file: ./TEST\1095\1095_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1095\1095_BM02OHNC.wav
# Processing file: ./TEST\1095\1095_BT01OENC.wav, Language Code: EN
# Copied to: english\1095\1095_BT01OENC.wav
# Processing file: ./TEST\1095\1095_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1095\1095_BT01OHNC.wav
# Processing speaker folder: ./TEST\1096
# Created English speaker folder: english\1096
# Created Favourite Language speaker folder: favourite_language\1096
# Processing file: ./TEST\1096\1096_BD01OENC.wav, Language Code: EN
# Copied to: english\1096\1096_BD01OENC.wav
# Processing file: ./TEST\1096\1096_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1096\1096_BD01OHNC.wav
# Processing file: ./TEST\1096\1096_BH01OENC.wav, Language Code: EN
# Copied to: english\1096\1096_BH01OENC.wav
# Processing file: ./TEST\1096\1096_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1096\1096_BH01OHNC.wav
# Processing file: ./TEST\1096\1096_BM01OENC.wav, Language Code: EN
# Copied to: english\1096\1096_BM01OENC.wav
# Processing file: ./TEST\1096\1096_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1096\1096_BM01OHNC.wav
# Processing file: ./TEST\1096\1096_BM02OENC.wav, Language Code: EN
# Copied to: english\1096\1096_BM02OENC.wav
# Processing file: ./TEST\1096\1096_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1096\1096_BM02OHNC.wav
# Processing file: ./TEST\1096\1096_BT01OENC.wav, Language Code: EN
# Copied to: english\1096\1096_BT01OENC.wav
# Processing file: ./TEST\1096\1096_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1096\1096_BT01OHNC.wav
# Processing speaker folder: ./TEST\1098
# Created English speaker folder: english\1098
# Created Favourite Language speaker folder: favourite_language\1098
# Processing file: ./TEST\1098\1098_BD01OENC.wav, Language Code: EN
# Copied to: english\1098\1098_BD01OENC.wav
# Processing file: ./TEST\1098\1098_BD01OTMC.wav, Language Code: TM
# Copied to: favourite_language\1098\1098_BD01OTMC.wav
# Processing file: ./TEST\1098\1098_BH01OENC.wav, Language Code: EN
# Copied to: english\1098\1098_BH01OENC.wav
# Processing file: ./TEST\1098\1098_BH01OTMC.wav, Language Code: TM
# Copied to: favourite_language\1098\1098_BH01OTMC.wav
# Processing file: ./TEST\1098\1098_BM01OENC.wav, Language Code: EN
# Copied to: english\1098\1098_BM01OENC.wav
# Processing file: ./TEST\1098\1098_BM01OTMC.wav, Language Code: TM
# Copied to: favourite_language\1098\1098_BM01OTMC.wav
# Processing file: ./TEST\1098\1098_BM02OENC.wav, Language Code: EN
# Copied to: english\1098\1098_BM02OENC.wav
# Processing file: ./TEST\1098\1098_BM02OTMC.wav, Language Code: TM
# Copied to: favourite_language\1098\1098_BM02OTMC.wav
# Processing file: ./TEST\1098\1098_BT01OENC.wav, Language Code: EN
# Copied to: english\1098\1098_BT01OENC.wav
# Processing file: ./TEST\1098\1098_BT01OTMC.wav, Language Code: TM
# Copied to: favourite_language\1098\1098_BT01OTMC.wav
# Processing speaker folder: ./TEST\1099
# Created English speaker folder: english\1099
# Created Favourite Language speaker folder: favourite_language\1099
# Processing file: ./TEST\1099\1099_BD01OENC.wav, Language Code: EN
# Copied to: english\1099\1099_BD01OENC.wav
# Processing file: ./TEST\1099\1099_BD01OTMC.wav, Language Code: TM
# Copied to: favourite_language\1099\1099_BD01OTMC.wav
# Processing file: ./TEST\1099\1099_BH01OENC.wav, Language Code: EN
# Copied to: english\1099\1099_BH01OENC.wav
# Processing file: ./TEST\1099\1099_BH01OTMC.wav, Language Code: TM
# Copied to: favourite_language\1099\1099_BH01OTMC.wav
# Processing file: ./TEST\1099\1099_BM01OENC.wav, Language Code: EN
# Copied to: english\1099\1099_BM01OENC.wav
# Processing file: ./TEST\1099\1099_BM01OTMC.wav, Language Code: TM
# Copied to: favourite_language\1099\1099_BM01OTMC.wav
# Processing file: ./TEST\1099\1099_BM02OENC.wav, Language Code: EN
# Copied to: english\1099\1099_BM02OENC.wav
# Processing file: ./TEST\1099\1099_BM02OTMC.wav, Language Code: TM
# Copied to: favourite_language\1099\1099_BM02OTMC.wav
# Processing file: ./TEST\1099\1099_BT01OENC.wav, Language Code: EN
# Copied to: english\1099\1099_BT01OENC.wav
# Processing file: ./TEST\1099\1099_BT01OTMC.wav, Language Code: TM
# Copied to: favourite_language\1099\1099_BT01OTMC.wav
# Processing speaker folder: ./TEST\1101
# Created English speaker folder: english\1101
# Created Favourite Language speaker folder: favourite_language\1101
# Processing file: ./TEST\1101\1101_BD01OENC.wav, Language Code: EN
# Copied to: english\1101\1101_BD01OENC.wav
# Processing file: ./TEST\1101\1101_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1101\1101_BD01OHNC.wav
# Processing file: ./TEST\1101\1101_BH01OENC.wav, Language Code: EN
# Copied to: english\1101\1101_BH01OENC.wav
# Processing file: ./TEST\1101\1101_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1101\1101_BH01OHNC.wav
# Processing file: ./TEST\1101\1101_BM01OENC.wav, Language Code: EN
# Copied to: english\1101\1101_BM01OENC.wav
# Processing file: ./TEST\1101\1101_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1101\1101_BM01OHNC.wav
# Processing file: ./TEST\1101\1101_BM02OENC.wav, Language Code: EN
# Copied to: english\1101\1101_BM02OENC.wav
# Processing file: ./TEST\1101\1101_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1101\1101_BM02OHNC.wav
# Processing file: ./TEST\1101\1101_BT01OENC.wav, Language Code: EN
# Copied to: english\1101\1101_BT01OENC.wav
# Processing file: ./TEST\1101\1101_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1101\1101_BT01OHNC.wav
# Processing speaker folder: ./TEST\1104
# Created English speaker folder: english\1104
# Created Favourite Language speaker folder: favourite_language\1104
# Processing file: ./TEST\1104\1104_BD01OENC.wav, Language Code: EN
# Copied to: english\1104\1104_BD01OENC.wav
# Processing file: ./TEST\1104\1104_BD01OTLC.wav, Language Code: TL
# Copied to: favourite_language\1104\1104_BD01OTLC.wav
# Processing file: ./TEST\1104\1104_BH01OENC.wav, Language Code: EN
# Copied to: english\1104\1104_BH01OENC.wav
# Processing file: ./TEST\1104\1104_BH01OTLC.wav, Language Code: TL
# Copied to: favourite_language\1104\1104_BH01OTLC.wav
# Processing file: ./TEST\1104\1104_BM01OENC.wav, Language Code: EN
# Copied to: english\1104\1104_BM01OENC.wav
# Processing file: ./TEST\1104\1104_BM01OTLC.wav, Language Code: TL
# Copied to: favourite_language\1104\1104_BM01OTLC.wav
# Processing file: ./TEST\1104\1104_BM02OENC.wav, Language Code: EN
# Copied to: english\1104\1104_BM02OENC.wav
# Processing file: ./TEST\1104\1104_BM02OTLC.wav, Language Code: TL
# Copied to: favourite_language\1104\1104_BM02OTLC.wav
# Processing file: ./TEST\1104\1104_BT01OENC.wav, Language Code: EN
# Copied to: english\1104\1104_BT01OENC.wav
# Processing file: ./TEST\1104\1104_BT01OTLC.wav, Language Code: TL
# Copied to: favourite_language\1104\1104_BT01OTLC.wav
# Processing speaker folder: ./TEST\1105
# Created English speaker folder: english\1105
# Created Favourite Language speaker folder: favourite_language\1105
# Processing file: ./TEST\1105\1105_BD01OENC.wav, Language Code: EN
# Copied to: english\1105\1105_BD01OENC.wav
# Processing file: ./TEST\1105\1105_BD01OTLC.wav, Language Code: TL
# Copied to: favourite_language\1105\1105_BD01OTLC.wav
# Processing file: ./TEST\1105\1105_BH01OENC.wav, Language Code: EN
# Copied to: english\1105\1105_BH01OENC.wav
# Processing file: ./TEST\1105\1105_BH01OTLC.wav, Language Code: TL
# Copied to: favourite_language\1105\1105_BH01OTLC.wav
# Processing file: ./TEST\1105\1105_BM01OENC.wav, Language Code: EN
# Copied to: english\1105\1105_BM01OENC.wav
# Processing file: ./TEST\1105\1105_BM01OTLC.wav, Language Code: TL
# Copied to: favourite_language\1105\1105_BM01OTLC.wav
# Processing file: ./TEST\1105\1105_BM02OENC.wav, Language Code: EN
# Copied to: english\1105\1105_BM02OENC.wav
# Processing file: ./TEST\1105\1105_BM02OTLC.wav, Language Code: TL
# Copied to: favourite_language\1105\1105_BM02OTLC.wav
# Processing file: ./TEST\1105\1105_BT01OENC.wav, Language Code: EN
# Copied to: english\1105\1105_BT01OENC.wav
# Processing file: ./TEST\1105\1105_BT01OTLC.wav, Language Code: TL
# Copied to: favourite_language\1105\1105_BT01OTLC.wav
# Processing speaker folder: ./TEST\1106
# Created English speaker folder: english\1106
# Created Favourite Language speaker folder: favourite_language\1106
# Processing file: ./TEST\1106\1106_BD01OENC.wav, Language Code: EN
# Copied to: english\1106\1106_BD01OENC.wav
# Processing file: ./TEST\1106\1106_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1106\1106_BD01OHNC.wav
# Processing file: ./TEST\1106\1106_BH01OENC.wav, Language Code: EN
# Copied to: english\1106\1106_BH01OENC.wav
# Processing file: ./TEST\1106\1106_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1106\1106_BH01OHNC.wav
# Processing file: ./TEST\1106\1106_BM01OENC.wav, Language Code: EN
# Copied to: english\1106\1106_BM01OENC.wav
# Processing file: ./TEST\1106\1106_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1106\1106_BM01OHNC.wav
# Processing file: ./TEST\1106\1106_BM02OENC.wav, Language Code: EN
# Copied to: english\1106\1106_BM02OENC.wav
# Processing file: ./TEST\1106\1106_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1106\1106_BM02OHNC.wav
# Processing file: ./TEST\1106\1106_BT01OENC.wav, Language Code: EN
# Copied to: english\1106\1106_BT01OENC.wav
# Processing file: ./TEST\1106\1106_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1106\1106_BT01OHNC.wav
# Processing speaker folder: ./TEST\1107
# Created English speaker folder: english\1107
# Created Favourite Language speaker folder: favourite_language\1107
# Processing file: ./TEST\1107\1107_BD01OENC.wav, Language Code: EN
# Copied to: english\1107\1107_BD01OENC.wav
# Processing file: ./TEST\1107\1107_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1107\1107_BD01OHNC.wav
# ...
# Copied to: favourite_language\1107\1107_BM01OHNC.wav
# Processing file: ./TEST\1107\1107_BM02OENC.wav, Language Code: EN
# Copied to: english\1107\1107_BM02OENC.wav
# Processing file: ./TEST\1107\1107_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1107\1107_BM02OHNC.wav
# Processing file: ./TEST\1107\1107_BT01OENC.wav, Language Code: EN
# Copied to: english\1107\1107_BT01OENC.wav
# Processing file: ./TEST\1107\1107_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1107\1107_BT01OHNC.wav
# Processing speaker folder: ./TEST\1108
# Created English speaker folder: english\1108
# Created Favourite Language speaker folder: favourite_language\1108
# Processing file: ./TEST\1108\1108_BD01OENC.wav, Language Code: EN
# Copied to: english\1108\1108_BD01OENC.wav
# Processing file: ./TEST\1108\1108_BD01OORC.wav, Language Code: OR
# Copied to: favourite_language\1108\1108_BD01OORC.wav
# Processing file: ./TEST\1108\1108_BH01OENC.wav, Language Code: EN
# Copied to: english\1108\1108_BH01OENC.wav
# Processing file: ./TEST\1108\1108_BH01OORC.wav, Language Code: OR
# Copied to: favourite_language\1108\1108_BH01OORC.wav
# Processing file: ./TEST\1108\1108_BM01OENC.wav, Language Code: EN
# Copied to: english\1108\1108_BM01OENC.wav
# Processing file: ./TEST\1108\1108_BM01OORC.wav, Language Code: OR
# Copied to: favourite_language\1108\1108_BM01OORC.wav
# Processing file: ./TEST\1108\1108_BM02OENC.wav, Language Code: EN
# Copied to: english\1108\1108_BM02OENC.wav
# Processing file: ./TEST\1108\1108_BM02OORC.wav, Language Code: OR
# Copied to: favourite_language\1108\1108_BM02OORC.wav
# Processing file: ./TEST\1108\1108_BT01OENC.wav, Language Code: EN
# Copied to: english\1108\1108_BT01OENC.wav
# Processing file: ./TEST\1108\1108_BT01OORC.wav, Language Code: OR
# Copied to: favourite_language\1108\1108_BT01OORC.wav
# Processing speaker folder: ./TEST\1109
# Created English speaker folder: english\1109
# Created Favourite Language speaker folder: favourite_language\1109
# Processing file: ./TEST\1109\1109_BD01OENC.wav, Language Code: EN
# Copied to: english\1109\1109_BD01OENC.wav
# Processing file: ./TEST\1109\1109_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1109\1109_BD01OHNC.wav
# Processing file: ./TEST\1109\1109_BH01OENC.wav, Language Code: EN
# Copied to: english\1109\1109_BH01OENC.wav
# Processing file: ./TEST\1109\1109_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1109\1109_BH01OHNC.wav
# Processing file: ./TEST\1109\1109_BM01OENC.wav, Language Code: EN
# Copied to: english\1109\1109_BM01OENC.wav
# Processing file: ./TEST\1109\1109_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1109\1109_BM01OHNC.wav
# Processing file: ./TEST\1109\1109_BM02OENC.wav, Language Code: EN
# Copied to: english\1109\1109_BM02OENC.wav
# Processing file: ./TEST\1109\1109_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\1109\1109_BM02OHNC.wav
# Processing file: ./TEST\1109\1109_BT01OENC.wav, Language Code: EN
# Copied to: english\1109\1109_BT01OENC.wav
# Processing file: ./TEST\1109\1109_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\1109\1109_BT01OHNC.wav
# Processing speaker folder: ./TEST\2046
# Created English speaker folder: english\2046
# Created Favourite Language speaker folder: favourite_language\2046
# Processing file: ./TEST\2046\2046_BD01OENC.wav, Language Code: EN
# Copied to: english\2046\2046_BD01OENC.wav
# Processing file: ./TEST\2046\2046_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2046\2046_BD01OHNC.wav
# Processing file: ./TEST\2046\2046_BH01OENC.wav, Language Code: EN
# Copied to: english\2046\2046_BH01OENC.wav
# Processing file: ./TEST\2046\2046_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2046\2046_BH01OHNC.wav
# Processing file: ./TEST\2046\2046_BM01OENC.wav, Language Code: EN
# Copied to: english\2046\2046_BM01OENC.wav
# Processing file: ./TEST\2046\2046_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2046\2046_BM01OHNC.wav
# Processing file: ./TEST\2046\2046_BM02OENC.wav, Language Code: EN
# Copied to: english\2046\2046_BM02OENC.wav
# Processing file: ./TEST\2046\2046_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\2046\2046_BM02OHNC.wav
# Processing file: ./TEST\2046\2046_BT01OENC.wav, Language Code: EN
# Copied to: english\2046\2046_BT01OENC.wav
# Processing file: ./TEST\2046\2046_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2046\2046_BT01OHNC.wav
# Processing speaker folder: ./TEST\2047
# Created English speaker folder: english\2047
# Created Favourite Language speaker folder: favourite_language\2047
# Processing file: ./TEST\2047\2047_BD01OENC.wav, Language Code: EN
# Copied to: english\2047\2047_BD01OENC.wav
# Processing file: ./TEST\2047\2047_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2047\2047_BD01OHNC.wav
# Processing file: ./TEST\2047\2047_BH01OENC.wav, Language Code: EN
# Copied to: english\2047\2047_BH01OENC.wav
# Processing file: ./TEST\2047\2047_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2047\2047_BH01OHNC.wav
# Processing file: ./TEST\2047\2047_BM01OENC.wav, Language Code: EN
# Copied to: english\2047\2047_BM01OENC.wav
# Processing file: ./TEST\2047\2047_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2047\2047_BM01OHNC.wav
# Processing file: ./TEST\2047\2047_BM02OENC.wav, Language Code: EN
# Copied to: english\2047\2047_BM02OENC.wav
# Processing file: ./TEST\2047\2047_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\2047\2047_BM02OHNC.wav
# Processing file: ./TEST\2047\2047_BT01OENC.wav, Language Code: EN
# Copied to: english\2047\2047_BT01OENC.wav
# Processing file: ./TEST\2047\2047_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2047\2047_BT01OHNC.wav
# Processing speaker folder: ./TEST\2048
# Created English speaker folder: english\2048
# Created Favourite Language speaker folder: favourite_language\2048
# Processing file: ./TEST\2048\2048_BD01OASC.wav, Language Code: AS
# Copied to: favourite_language\2048\2048_BD01OASC.wav
# Processing file: ./TEST\2048\2048_BD01OENC.wav, Language Code: EN
# Copied to: english\2048\2048_BD01OENC.wav
# Processing file: ./TEST\2048\2048_BH01OASC.wav, Language Code: AS
# Copied to: favourite_language\2048\2048_BH01OASC.wav
# Processing file: ./TEST\2048\2048_BH01OENC.wav, Language Code: EN
# Copied to: english\2048\2048_BH01OENC.wav
# Processing file: ./TEST\2048\2048_BM01OASC.wav, Language Code: AS
# Copied to: favourite_language\2048\2048_BM01OASC.wav
# Processing file: ./TEST\2048\2048_BM01OENC.wav, Language Code: EN
# Copied to: english\2048\2048_BM01OENC.wav
# Processing file: ./TEST\2048\2048_BM02OASC.wav, Language Code: AS
# Copied to: favourite_language\2048\2048_BM02OASC.wav
# Processing file: ./TEST\2048\2048_BM02OENC.wav, Language Code: EN
# Copied to: english\2048\2048_BM02OENC.wav
# Processing file: ./TEST\2048\2048_BT01OASC.wav, Language Code: AS
# Copied to: favourite_language\2048\2048_BT01OASC.wav
# Processing file: ./TEST\2048\2048_BT01OENC.wav, Language Code: EN
# Copied to: english\2048\2048_BT01OENC.wav
# Processing speaker folder: ./TEST\2050
# Created English speaker folder: english\2050
# Created Favourite Language speaker folder: favourite_language\2050
# Processing file: ./TEST\2050\2050_BD01OENC.wav, Language Code: EN
# Copied to: english\2050\2050_BD01OENC.wav
# Processing file: ./TEST\2050\2050_BD01OTMC.wav, Language Code: TM
# Copied to: favourite_language\2050\2050_BD01OTMC.wav
# Processing file: ./TEST\2050\2050_BH01OENC.wav, Language Code: EN
# Copied to: english\2050\2050_BH01OENC.wav
# Processing file: ./TEST\2050\2050_BH01OTMC.wav, Language Code: TM
# Copied to: favourite_language\2050\2050_BH01OTMC.wav
# Processing file: ./TEST\2050\2050_BM01OENC.wav, Language Code: EN
# Copied to: english\2050\2050_BM01OENC.wav
# Processing file: ./TEST\2050\2050_BM01OTMC.wav, Language Code: TM
# Copied to: favourite_language\2050\2050_BM01OTMC.wav
# Processing file: ./TEST\2050\2050_BM02OENC.wav, Language Code: EN
# Copied to: english\2050\2050_BM02OENC.wav
# Processing file: ./TEST\2050\2050_BM02OTMC.wav, Language Code: TM
# Copied to: favourite_language\2050\2050_BM02OTMC.wav
# Processing file: ./TEST\2050\2050_BT01OENC.wav, Language Code: EN
# Copied to: english\2050\2050_BT01OENC.wav
# Processing file: ./TEST\2050\2050_BT01OTMC.wav, Language Code: TM
# Copied to: favourite_language\2050\2050_BT01OTMC.wav
# Processing speaker folder: ./TEST\2056
# Created English speaker folder: english\2056
# Created Favourite Language speaker folder: favourite_language\2056
# Processing file: ./TEST\2056\2056_BD01OBNC.wav, Language Code: BN
# Copied to: favourite_language\2056\2056_BD01OBNC.wav
# Processing file: ./TEST\2056\2056_BD01OENC.wav, Language Code: EN
# Copied to: english\2056\2056_BD01OENC.wav
# Processing file: ./TEST\2056\2056_BH01OBNC.wav, Language Code: BN
# Copied to: favourite_language\2056\2056_BH01OBNC.wav
# Processing file: ./TEST\2056\2056_BH01OENC.wav, Language Code: EN
# Copied to: english\2056\2056_BH01OENC.wav
# Processing file: ./TEST\2056\2056_BM01OBNC.wav, Language Code: BN
# Copied to: favourite_language\2056\2056_BM01OBNC.wav
# Processing file: ./TEST\2056\2056_BM01OENC.wav, Language Code: EN
# Copied to: english\2056\2056_BM01OENC.wav
# Processing file: ./TEST\2056\2056_BM02OBNC.wav, Language Code: BN
# Copied to: favourite_language\2056\2056_BM02OBNC.wav
# Processing file: ./TEST\2056\2056_BM02OENC.wav, Language Code: EN
# Copied to: english\2056\2056_BM02OENC.wav
# Processing file: ./TEST\2056\2056_BT01OBNC.wav, Language Code: BN
# Copied to: favourite_language\2056\2056_BT01OBNC.wav
# Processing file: ./TEST\2056\2056_BT01OENC.wav, Language Code: EN
# Copied to: english\2056\2056_BT01OENC.wav
# Processing speaker folder: ./TEST\2083
# Created English speaker folder: english\2083
# Created Favourite Language speaker folder: favourite_language\2083
# Processing file: ./TEST\2083\2083_BD01OENC.wav, Language Code: EN
# Copied to: english\2083\2083_BD01OENC.wav
# Processing file: ./TEST\2083\2083_BD01OTMC.wav, Language Code: TM
# Copied to: favourite_language\2083\2083_BD01OTMC.wav
# Processing file: ./TEST\2083\2083_BH01OENC.wav, Language Code: EN
# Copied to: english\2083\2083_BH01OENC.wav
# Processing file: ./TEST\2083\2083_BH01OTMC.wav, Language Code: TM
# Copied to: favourite_language\2083\2083_BH01OTMC.wav
# Processing file: ./TEST\2083\2083_BM01OENC.wav, Language Code: EN
# Copied to: english\2083\2083_BM01OENC.wav
# Processing file: ./TEST\2083\2083_BM01OTMC.wav, Language Code: TM
# Copied to: favourite_language\2083\2083_BM01OTMC.wav
# Processing file: ./TEST\2083\2083_BM02OENC.wav, Language Code: EN
# Copied to: english\2083\2083_BM02OENC.wav
# Processing file: ./TEST\2083\2083_BM02OTMC.wav, Language Code: TM
# Copied to: favourite_language\2083\2083_BM02OTMC.wav
# Processing file: ./TEST\2083\2083_BT01OENC.wav, Language Code: EN
# Copied to: english\2083\2083_BT01OENC.wav
# Processing file: ./TEST\2083\2083_BT01OTMC.wav, Language Code: TM
# Copied to: favourite_language\2083\2083_BT01OTMC.wav
# Processing speaker folder: ./TEST\2097
# Created English speaker folder: english\2097
# Created Favourite Language speaker folder: favourite_language\2097
# Processing file: ./TEST\2097\2097_BD01OENC.wav, Language Code: EN
# Copied to: english\2097\2097_BD01OENC.wav
# Processing file: ./TEST\2097\2097_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2097\2097_BD01OHNC.wav
# Processing file: ./TEST\2097\2097_BH01OENC.wav, Language Code: EN
# Copied to: english\2097\2097_BH01OENC.wav
# Processing file: ./TEST\2097\2097_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2097\2097_BH01OHNC.wav
# Processing file: ./TEST\2097\2097_BM01OENC.wav, Language Code: EN
# Copied to: english\2097\2097_BM01OENC.wav
# Processing file: ./TEST\2097\2097_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2097\2097_BM01OHNC.wav
# Processing file: ./TEST\2097\2097_BM02OENC.wav, Language Code: EN
# Copied to: english\2097\2097_BM02OENC.wav
# Processing file: ./TEST\2097\2097_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\2097\2097_BM02OHNC.wav
# Processing file: ./TEST\2097\2097_BT01OENC.wav, Language Code: EN
# Copied to: english\2097\2097_BT01OENC.wav
# Processing file: ./TEST\2097\2097_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2097\2097_BT01OHNC.wav
# Processing speaker folder: ./TEST\2100
# Created English speaker folder: english\2100
# Created Favourite Language speaker folder: favourite_language\2100
# Processing file: ./TEST\2100\2100_BD01OENC.wav, Language Code: EN
# Copied to: english\2100\2100_BD01OENC.wav
# Processing file: ./TEST\2100\2100_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2100\2100_BD01OHNC.wav
# Processing file: ./TEST\2100\2100_BH01OENC.wav, Language Code: EN
# Copied to: english\2100\2100_BH01OENC.wav
# Processing file: ./TEST\2100\2100_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2100\2100_BH01OHNC.wav
# Processing file: ./TEST\2100\2100_BM01OENC.wav, Language Code: EN
# Copied to: english\2100\2100_BM01OENC.wav
# Processing file: ./TEST\2100\2100_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2100\2100_BM01OHNC.wav
# Processing file: ./TEST\2100\2100_BM02OENC.wav, Language Code: EN
# Copied to: english\2100\2100_BM02OENC.wav
# Processing file: ./TEST\2100\2100_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\2100\2100_BM02OHNC.wav
# Processing file: ./TEST\2100\2100_BT01OENC.wav, Language Code: EN
# Copied to: english\2100\2100_BT01OENC.wav
# Processing file: ./TEST\2100\2100_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2100\2100_BT01OHNC.wav
# Processing speaker folder: ./TEST\2102
# Created English speaker folder: english\2102
# Created Favourite Language speaker folder: favourite_language\2102
# Processing file: ./TEST\2102\2102_BD01OASC.wav, Language Code: AS
# Copied to: favourite_language\2102\2102_BD01OASC.wav
# Processing file: ./TEST\2102\2102_BD01OENC.wav, Language Code: EN
# Copied to: english\2102\2102_BD01OENC.wav
# Processing file: ./TEST\2102\2102_BH01OASC.wav, Language Code: AS
# Copied to: favourite_language\2102\2102_BH01OASC.wav
# Processing file: ./TEST\2102\2102_BH01OENC.wav, Language Code: EN
# Copied to: english\2102\2102_BH01OENC.wav
# Processing file: ./TEST\2102\2102_BM01OASC.wav, Language Code: AS
# Copied to: favourite_language\2102\2102_BM01OASC.wav
# Processing file: ./TEST\2102\2102_BM01OENC.wav, Language Code: EN
# Copied to: english\2102\2102_BM01OENC.wav
# Processing file: ./TEST\2102\2102_BM02OASC.wav, Language Code: AS
# Copied to: favourite_language\2102\2102_BM02OASC.wav
# Processing file: ./TEST\2102\2102_BM02OENC.wav, Language Code: EN
# Copied to: english\2102\2102_BM02OENC.wav
# Processing file: ./TEST\2102\2102_BT01OASC.wav, Language Code: AS
# Copied to: favourite_language\2102\2102_BT01OASC.wav
# Processing file: ./TEST\2102\2102_BT01OENC.wav, Language Code: EN
# Copied to: english\2102\2102_BT01OENC.wav
# Processing speaker folder: ./TEST\2103
# Created English speaker folder: english\2103
# Created Favourite Language speaker folder: favourite_language\2103
# Processing file: ./TEST\2103\2103_BD01OENC.wav, Language Code: EN
# Copied to: english\2103\2103_BD01OENC.wav
# Processing file: ./TEST\2103\2103_BD01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2103\2103_BD01OHNC.wav
# Processing file: ./TEST\2103\2103_BH01OENC.wav, Language Code: EN
# Copied to: english\2103\2103_BH01OENC.wav
# Processing file: ./TEST\2103\2103_BH01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2103\2103_BH01OHNC.wav
# Processing file: ./TEST\2103\2103_BM01OENC.wav, Language Code: EN
# Copied to: english\2103\2103_BM01OENC.wav
# Processing file: ./TEST\2103\2103_BM01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2103\2103_BM01OHNC.wav
# Processing file: ./TEST\2103\2103_BM02OENC.wav, Language Code: EN
# Copied to: english\2103\2103_BM02OENC.wav
# Processing file: ./TEST\2103\2103_BM02OHNC.wav, Language Code: HN
# Copied to: favourite_language\2103\2103_BM02OHNC.wav
# Processing file: ./TEST\2103\2103_BT01OENC.wav, Language Code: EN
# Copied to: english\2103\2103_BT01OENC.wav
# Processing file: ./TEST\2103\2103_BT01OHNC.wav, Language Code: HN
# Copied to: favourite_language\2103\2103_BT01OHNC.wav
# File segregation process completed (files copied).

# %%
import os

def get_speaker_id(filename):
    """Extracts the speaker ID (first 4 digits before underscore) from filename."""
    parts = filename.split('_')
    if len(parts) < 2:
        print(f"[!] Filename format invalid: {filename}")
        return None
    return parts[0]

def generate_labels(folder1, folder2, output_file='labels.txt'):
    if not os.path.isdir(folder1) or not os.path.isdir(folder2):
        print("[✗] One or both folders do not exist.")
        return

    files1 = sorted([f for f in os.listdir(folder1) if f.endswith('.wav')])
    files2 = sorted([f for f in os.listdir(folder2) if f.endswith('.wav')])

    print(f"[i] Found {len(files1)} files in {folder1}")
    print(f"[i] Found {len(files2)} files in {folder2}")

    if not files1 or not files2:
        print("[✗] No .wav files to process.")
        return

    count = 0
    with open(output_file, 'w') as out:
        for file1 in files1:
            speaker1 = get_speaker_id(file1)
            if not speaker1:
                continue
            for file2 in files2:
                speaker2 = get_speaker_id(file2)
                if not speaker2:
                    continue
                label = 1 if speaker1 == speaker2 else 0
                out.write(f"{label} {os.path.join(folder1, file1)} {os.path.join(folder2, file2)}\n")
                count += 1

    print(f"[✓] Labels saved to {output_file} — {count} pairs written.")

# Example usage
generate_labels('./english', './favourite_language', 'english_to_other.txt')
# Out:
# [i] Found 0 files in ./english
# [i] Found 0 files in ./favourite_language
# [✗] No .wav files to process.

# %%
import os

def collect_audio_files(audio_dir):
    """
    Recursively collect audio filenames and their speaker IDs
    based on the immediate subfolder under `audio_dir`.
    """
    audio_data = []

    for root, dirs, files in os.walk(audio_dir):
        for file in files:
            if file.endswith(('.wav', '.mp3', '.amr')):
                speaker_id = os.path.relpath(root, audio_dir).split(os.sep)[0]
                key = f"{speaker_id}@{file}"
                audio_data.append((speaker_id, key))

    return audio_data

def compare_speaker_ids_between_dirs(audio_dir1, audio_dir2, output_filename):
    """
    Compares speaker IDs between two directories and writes pairwise labels.

    Args:
        audio_dir1 (str): Path to the first audio directory.
        audio_dir2 (str): Path to the second audio directory.
        output_filename (str): Output file to write labels and file pairs.
    """
    audio_data1 = collect_audio_files(audio_dir1)
    audio_data2 = collect_audio_files(audio_dir2)

    with open(output_filename, 'w') as outfile:
        for speaker_id1, key1 in audio_data1:
            for speaker_id2, key2 in audio_data2:
                label = 1 if speaker_id1 == speaker_id2 else 0
                outfile.write(f"{label} {key1} {key2}\n")

    print(f"Speaker ID comparison between folders complete. Results saved to '{output_filename}'")

if __name__ == "__main__":
    audio_directory1 = input("Enter the FIRST directory containing audio files: ")
    audio_directory2 = input("Enter the SECOND directory containing audio files: ")
    output_file = input("Enter the name for the output text file (e.g., comparison.txt): ")

    compare_speaker_ids_between_dirs(audio_directory1, audio_directory2, output_file)
# Out:
# Speaker ID comparison between folders complete. Results saved to 'others_to_english.txt'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# t-sne plot test

# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# 🔧 Step 1: Set your pkl path here
pkl_path = 'your_file_path_here/embeddings.pkl'  # e.g., 'C:/Users/Lokesh/Desktop/embeddings.pkl'

# Step 2: Load the dictionary from pkl
with open(pkl_path, 'rb') as f:
    data = pickle.load(f)  # format: {filename: embedding_vector}

# Step 3: Extract embeddings and labels
keys = list(data.keys())
embeddings = np.array([data[k] for k in keys])

# Optional: Generate simple numeric labels (for color mapping)
labels = np.arange(len(keys))

# Step 4: Run PCA (2 components)
pca = PCA(n_components=2)
pca_result = pca.fit_transform(embeddings)

# Step 5: Plot
plt.figure(figsize=(12, 9))
scatter = plt.scatter(pca_result[:, 0], pca_result[:, 1], c=labels, cmap='tab10', s=50)
plt.title('PCA of Speaker Embeddings')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)

# Annotate a few samples (for readability)
for i in range(0, len(keys), max(1, len(keys) // 20)):
    plt.annotate(keys[i].split('@')[0], (pca_result[i, 0], pca_result[i, 1]))

# Step 6: Save plot in the same folder
save_path = os.path.join(os.path.dirname(pkl_path), 'pca_plot.png')
plt.savefig(save_path)
plt.show()

print(f"✅ PCA plot saved at: {save_path}")

# %% [markdown]
# PCA plot test

# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# 🔧 Step 1: Set your pkl path here
pkl_path = 'C:\Lokesh\speaker-verification\evaluation_speaker_verification\speaker_embeddings-IMSV_English.pkl'  # e.g., 'C:/Users/Lokesh/Desktop/embeddings.pkl'

# Step 2: Load the dictionary from pkl
with open(pkl_path, 'rb') as f:
    data = pickle.load(f)  # data is a dict: {filename: embedding_vector}

# Step 3: Extract embeddings and labels
keys = list(data.keys())
embeddings = np.array([data[k] for k in keys])

# Optional: Generate simple numeric labels (like 0, 1, 2...) for plotting
labels = np.arange(len(keys))

# Step 4: Run t-SNE
tsne = TSNE(n_components=2, perplexity=30, n_iter=1000, random_state=42)
tsne_result = tsne.fit_transform(embeddings)

# Step 5: Plot
plt.figure(figsize=(12, 9))
scatter = plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=labels, cmap='tab10', s=50)
plt.title('t-SNE of Speaker Embeddings')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid(True)

# Optionally annotate a few points (not all to avoid clutter)
for i in range(0, len(keys), max(1, len(keys) // 20)):
    plt.annotate(keys[i].split('@')[0], (tsne_result[i, 0], tsne_result[i, 1]))

# Step 6: Save the plot
save_path = os.path.join(os.path.dirname(pkl_path), 'tsne_plot.png')
plt.savefig(save_path)
plt.show()

print(f"✅ t-SNE plot saved at: {save_path}")
# Out:
# ✅ t-SNE plot saved at: C:\Lokesh\speaker-verification\evaluation_speaker_verification\tsne_plot.png

# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# 🔧 Set your .pkl file path here
pkl_path = 'C:\Lokesh\speaker-verification\evaluation_speaker_verification\speaker_embeddings-IMSV_English.pkl'  # Example: 'C:/Users/Lokesh/Desktop/embeddings.pkl'

# 📦 Load the speaker embeddings
with open(pkl_path, 'rb') as f:
    data = pickle.load(f)  # Expected format: { "speaker_id@file.wav": [embedding_vector] }

# 🎯 Extract data
keys = list(data.keys())
embeddings = np.array([data[k] for k in keys])

# 🎨 Assign numerical labels (if needed for coloring)
labels = np.arange(len(keys))

# 📐 Optional: Standardize before PCA (optional, but often helps)
scaler = StandardScaler()
embeddings_std = scaler.fit_transform(embeddings)

# 🧠 Apply PCA (2 components for 2D plotting)
pca = PCA(n_components=2)
pca_result = pca.fit_transform(embeddings_std)

# 📊 Plot PCA
plt.figure(figsize=(10, 8))
scatter = plt.scatter(pca_result[:, 0], pca_result[:, 1], c=labels, cmap='tab20', s=50, alpha=0.8)
plt.title('PCA of Speaker Embeddings')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)

# Optional: annotate a few points with speaker IDs
for i in range(0, len(keys), max(1, len(keys)//30)):
    speaker_id = keys[i].split('@')[0]
    plt.annotate(speaker_id, (pca_result[i, 0], pca_result[i, 1]), fontsize=8, alpha=0.7)

# 💾 Save plot in the same folder as .pkl
save_path = os.path.join(os.path.dirname(pkl_path), 'pca_plot.png')
plt.savefig(save_path)
plt.show()

print(f"✅ PCA plot saved at: {save_path}")
# Out:
# ✅ PCA plot saved at: C:\Lokesh\speaker-verification\evaluation_speaker_verification\pca_plot.png

# %% [markdown]
# Seperate files on the basis of sensors

# %%
import os
import shutil

sensor_map = {
    'H01': 'Headset_Microphone',
    'T01': 'Tablet_PC',
    'D01': 'Digital_Voice_Recorder',
    'M01': 'Mobile_Nokia_Offline',
    'M02': 'Mobile_SonyEricsson_Offline',
    'M03': 'Mobile_Nokia_Online',
    'M04': 'Mobile_Offline_Handsfree'
}

def sort_nested_wav_files_with_speaker_folders(test_root_dir):
    sorted_dir = os.path.join(os.path.dirname(test_root_dir), 'sorted')
    os.makedirs(sorted_dir, exist_ok=True)

    speaker_folders = [f for f in os.listdir(test_root_dir) if os.path.isdir(os.path.join(test_root_dir, f))]
    print(f"Found {len(speaker_folders)} speaker folders inside '{test_root_dir}'")

    for speaker_id in speaker_folders:
        speaker_path = os.path.join(test_root_dir, speaker_id)
        wav_files = os.listdir(speaker_path)

        for filename in wav_files:
            if filename.lower().endswith(".wav"):
                parts = filename.split('_')
                if len(parts) >= 2 and len(parts[1]) >= 4:
                    sensor_id = parts[1][1:4]  # ✅ Correct extraction of 3-letter sensor ID
                    sensor_name = sensor_map.get(sensor_id, 'Unknown_Sensor')

                    dest_dir = os.path.join(sorted_dir, sensor_name, speaker_id)
                    os.makedirs(dest_dir, exist_ok=True)

                    src_path = os.path.join(speaker_path, filename)
                    dest_path = os.path.join(dest_dir, filename)

                    shutil.copy2(src_path, dest_path)
                    print(f"Copied {filename} → {dest_dir}")
                else:
                    print(f"Skipped: {filename} — invalid naming pattern")
            else:
                print(f"Skipped: {filename} — not a .wav file")

# 👇 Paste your path here
your_test_folder = r"C:\Lokesh\speaker-verification\evaluation_speaker_verification\TEST"
sort_nested_wav_files_with_speaker_folders(your_test_folder)
# Out:
# Found 50 speaker folders inside 'C:\Lokesh\speaker-verification\evaluation_speaker_verification\TEST'
# Copied 1043_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1043
# Copied 1043_BD01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1043
# Copied 1043_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1043
# Copied 1043_BH01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1043
# Copied 1043_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1043
# Copied 1043_BM01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1043
# Copied 1043_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1043
# Copied 1043_BM02OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1043
# Copied 1043_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\1043
# Copied 1043_BT01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\1043
# Copied 1066_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1066
# Copied 1066_BD01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1066
# Copied 1066_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1066
# Copied 1066_BH01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1066
# Copied 1066_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1066
# Copied 1066_BM01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1066
# Copied 1066_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1066
# Copied 1066_BM02OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1066
# Copied 1066_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\1066
# Copied 1066_BT01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\1066
# Copied 1067_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1067
# Copied 1067_BD01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1067
# Copied 1067_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1067
# Copied 1067_BH01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1067
# Copied 1067_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1067
# Copied 1067_BM01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1067
# Copied 1067_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1067
# Copied 1067_BM02OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1067
# Copied 1067_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\1067
# Copied 1067_BT01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\1067
# Copied 1068_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1068
# Copied 1068_BD01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1068
# Copied 1068_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1068
# Copied 1068_BH01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1068
# Copied 1068_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1068
# Copied 1068_BM01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1068
# Copied 1068_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1068
# Copied 1068_BM02OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1068
# Copied 1068_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\1068
# Copied 1068_BT01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\1068
# Copied 1069_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1069
# Copied 1069_BD01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1069
# Copied 1069_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1069
# Copied 1069_BH01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1069
# Copied 1069_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1069
# Copied 1069_BM01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1069
# Copied 1069_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1069
# Copied 1069_BM02OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1069
# Copied 1069_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\1069
# Copied 1069_BT01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\1069
# Copied 1070_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1070
# Copied 1070_BD01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1070
# Copied 1070_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1070
# Copied 1070_BH01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1070
# Copied 1070_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1070
# Copied 1070_BM01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1070
# Copied 1070_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1070
# Copied 1070_BM02OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1070
# Copied 1070_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\1070
# Copied 1070_BT01OORC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\1070
# Copied 1071_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1071
# Copied 1071_BD01OMLC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\1071
# Copied 1071_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1071
# Copied 1071_BH01OMLC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\1071
# Copied 1071_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1071
# Copied 1071_BM01OMLC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\1071
# Copied 1071_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1071
# Copied 1071_BM02OMLC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\1071
# Copied 1071_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\1071
# Copied 1071_BT01OMLC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\
BT01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2047
# Copied 2048_BD01OASC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2048
# Copied 2048_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2048
# Copied 2048_BH01OASC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2048
# Copied 2048_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2048
# Copied 2048_BM01OASC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2048
# Copied 2048_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2048
# Copied 2048_BM02OASC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2048
# Copied 2048_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2048
# Copied 2048_BT01OASC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2048
# Copied 2048_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2048
# Copied 2050_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2050
# Copied 2050_BD01OTMC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2050
# Copied 2050_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2050
# Copied 2050_BH01OTMC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2050
# Copied 2050_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2050
# Copied 2050_BM01OTMC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2050
# Copied 2050_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2050
# Copied 2050_BM02OTMC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2050
# Copied 2050_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2050
# Copied 2050_BT01OTMC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2050
# Copied 2056_BD01OBNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2056
# Copied 2056_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2056
# Copied 2056_BH01OBNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2056
# Copied 2056_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2056
# Copied 2056_BM01OBNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2056
# Copied 2056_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2056
# Copied 2056_BM02OBNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2056
# Copied 2056_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2056
# Copied 2056_BT01OBNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2056
# Copied 2056_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2056
# Copied 2083_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2083
# Copied 2083_BD01OTMC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2083
# Copied 2083_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2083
# Copied 2083_BH01OTMC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2083
# Copied 2083_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2083
# Copied 2083_BM01OTMC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2083
# Copied 2083_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2083
# Copied 2083_BM02OTMC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2083
# Copied 2083_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2083
# Copied 2083_BT01OTMC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2083
# Copied 2097_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2097
# Copied 2097_BD01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2097
# Copied 2097_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2097
# Copied 2097_BH01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2097
# Copied 2097_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2097
# Copied 2097_BM01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2097
# Copied 2097_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2097
# Copied 2097_BM02OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2097
# Copied 2097_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2097
# Copied 2097_BT01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2097
# Copied 2100_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2100
# Copied 2100_BD01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2100
# Copied 2100_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2100
# Copied 2100_BH01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2100
# Copied 2100_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2100
# Copied 2100_BM01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2100
# Copied 2100_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2100
# Copied 2100_BM02OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2100
# Copied 2100_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2100
# Copied 2100_BT01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2100
# Copied 2102_BD01OASC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2102
# Copied 2102_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2102
# Copied 2102_BH01OASC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2102
# Copied 2102_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2102
# Copied 2102_BM01OASC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2102
# Copied 2102_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2102
# Copied 2102_BM02OASC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2102
# Copied 2102_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2102
# Copied 2102_BT01OASC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2102
# Copied 2102_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2102
# Copied 2103_BD01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2103
# Copied 2103_BD01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Digital_Voice_Recorder\2103
# Copied 2103_BH01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2103
# Copied 2103_BH01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Headset_Microphone\2103
# Copied 2103_BM01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2103
# Copied 2103_BM01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_Nokia_Offline\2103
# Copied 2103_BM02OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2103
# Copied 2103_BM02OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Mobile_SonyEricsson_Offline\2103
# Copied 2103_BT01OENC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2103
# Copied 2103_BT01OHNC.wav → C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted\Tablet_PC\2103

# %% [markdown]
# Generate Trail files for different sensors

# %%
import os
from collections import defaultdict

def generate_sensorwise_verification_pairs(sorted_root, output_folder='comparison_files', max_impostors=5):
    os.makedirs(output_folder, exist_ok=True)

    # Structure: sensor -> speaker_id -> list of files
    sensor_data = defaultdict(lambda: defaultdict(list))

    # STEP 1: Collect data from folder structure
    for sensor in os.listdir(sorted_root):
        sensor_path = os.path.join(sorted_root, sensor)
        if not os.path.isdir(sensor_path):
            continue
        for speaker_id in os.listdir(sensor_path):
            speaker_path = os.path.join(sensor_path, speaker_id)
            for fname in os.listdir(speaker_path):
                if fname.endswith(".wav"):
                    identifier = f"{speaker_id}@{fname}"
                    sensor_data[sensor][speaker_id].append(identifier)

    # STEP 2: Generate 25 comparison files
    for train_sensor in sensor_data:
        for test_sensor in sensor_data:
            filename = f"{train_sensor}_to_{test_sensor}.txt".replace(" ", "_")
            output_path = os.path.join(output_folder, filename)

            with open(output_path, 'w') as out:
                for speaker_id in sensor_data[train_sensor]:
                    train_files = sensor_data[train_sensor][speaker_id]
                    test_files = sensor_data[test_sensor].get(speaker_id, [])

                    # Genuine comparisons (same speaker, label = 1)
                    for f1 in train_files:
                        for f2 in test_files:
                            if f1 != f2:
                                out.write(f"1 {f1} {f2}\n")

                        # Impostor comparisons (different speakers, label = 0)
                        impostor_count = 0
                        for other_speaker in sensor_data[test_sensor]:
                            if other_speaker != speaker_id:
                                for imp_file in sensor_data[test_sensor][other_speaker]:
                                    out.write(f"0 {f1} {imp_file}\n")
                                    impostor_count += 1
                                    if impostor_count >= max_impostors:
                                        break
                            if impostor_count >= max_impostors:
                                break

            print(f"[✓] Created: {filename}")

# --- JUST CALL THIS FUNCTION WITH YOUR FOLDER PATH ---
# Example:
generate_sensorwise_verification_pairs(
    sorted_root=r"C:\Lokesh\speaker-verification\evaluation_speaker_verification\sorted"
)
# Out:
# [✓] Created: Digital_Voice_Recorder_to_Digital_Voice_Recorder.txt
# [✓] Created: Digital_Voice_Recorder_to_Headset_Microphone.txt
# [✓] Created: Digital_Voice_Recorder_to_Mobile_Nokia_Offline.txt
# [✓] Created: Digital_Voice_Recorder_to_Mobile_SonyEricsson_Offline.txt
# [✓] Created: Digital_Voice_Recorder_to_Tablet_PC.txt
# [✓] Created: Headset_Microphone_to_Digital_Voice_Recorder.txt
# [✓] Created: Headset_Microphone_to_Headset_Microphone.txt
# [✓] Created: Headset_Microphone_to_Mobile_Nokia_Offline.txt
# [✓] Created: Headset_Microphone_to_Mobile_SonyEricsson_Offline.txt
# [✓] Created: Headset_Microphone_to_Tablet_PC.txt
# [✓] Created: Mobile_Nokia_Offline_to_Digital_Voice_Recorder.txt
# [✓] Created: Mobile_Nokia_Offline_to_Headset_Microphone.txt
# [✓] Created: Mobile_Nokia_Offline_to_Mobile_Nokia_Offline.txt
# [✓] Created: Mobile_Nokia_Offline_to_Mobile_SonyEricsson_Offline.txt
# [✓] Created: Mobile_Nokia_Offline_to_Tablet_PC.txt
# [✓] Created: Mobile_SonyEricsson_Offline_to_Digital_Voice_Recorder.txt
# [✓] Created: Mobile_SonyEricsson_Offline_to_Headset_Microphone.txt
# [✓] Created: Mobile_SonyEricsson_Offline_to_Mobile_Nokia_Offline.txt
# [✓] Created: Mobile_SonyEricsson_Offline_to_Mobile_SonyEricsson_Offline.txt
# [✓] Created: Mobile_SonyEricsson_Offline_to_Tablet_PC.txt
# [✓] Created: Tablet_PC_to_Digital_Voice_Recorder.txt
# [✓] Created: Tablet_PC_to_Headset_Microphone.txt
# [✓] Created: Tablet_PC_to_Mobile_Nokia_Offline.txt
# [✓] Created: Tablet_PC_to_Mobile_SonyEricsson_Offline.txt
# [✓] Created: Tablet_PC_to_Tablet_PC.txt
